# %% [markdown]
# ****Caricamento test.jsonl e train.jsonl****

# %%
import pandas as pd
import numpy as np
import json
import warnings
from tqdm.auto import tqdm

# --- 1. Import di Scikit-learn ---
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression   # <-- Il tuo modello
from sklearn.preprocessing import StandardScaler, OneHotEncoder, RobustScaler # <-- StandardScaler è incluso
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score
from sklearn.exceptions import ConvergenceWarning
from xgboost import XGBClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.model_selection import cross_val_score

# %%
try:
    train_df = pd.read_json('/kaggle/input/fds-pokemon-battles-prediction-2025/train.jsonl', lines=True)
    test_df = pd.read_json('/kaggle/input/fds-pokemon-battles-prediction-2025/test.jsonl', lines=True)
    
    # Convertiamo subito il target in 1 (Vittoria) e 0 (Sconfitta)
    if 'player_won' in train_df.columns:
        train_df['player_won'] = train_df['player_won'].astype(int)
    print("Caricamento riuscito!")
except Exception as e:
    print(f"Errore nel caricamento dati: {e}")

#####
riga_da_rimuovere = 4877

# Usiamo un controllo per sicurezza, nel caso la riga non esista
if riga_da_rimuovere in train_df.index:
    train_df = train_df.drop(riga_da_rimuovere)
    print(f"Riga {riga_da_rimuovere} rimossa con successo.")
else:
    print(f"Riga {riga_da_rimuovere} non trovata (forse già rimossa o non presente).")

filtro_livello_100 = train_df['p1_team_details'].apply(
    lambda team_list: all(pokemon.get('level') == 100 for pokemon in team_list)
)

train_df = train_df[filtro_livello_100]
# Out:
# Caricamento riuscito!
# Riga 4877 rimossa con successo.

# %%
# Mappa di efficacia dei tipi per la Generazione 1
# Nota: 'Special' in Gen 1 copre sia Atk Sp. che Def Sp.
# Non ci sono tipi Dark, Steel, o Fairy.
TYPE_CHART_GEN1 = {
    'NORMAL': {'ROCK': 0.5, 'GHOST': 0.0},
    'FIRE': {'FIRE': 0.5, 'WATER': 0.5, 'GRASS': 2.0, 'ICE': 2.0, 'BUG': 2.0, 'ROCK': 0.5},
    'WATER': {'FIRE': 2.0, 'WATER': 0.5, 'GRASS': 0.5, 'GROUND': 2.0, 'ROCK': 2.0, 'DRAGON': 0.5},
    'ELECTRIC': {'WATER': 2.0, 'ELECTRIC': 0.5, 'GRASS': 0.5, 'GROUND': 0.0, 'FLYING': 2.0, 'DRAGON': 0.5},
    'GRASS': {'FIRE': 0.5, 'WATER': 2.0, 'ELECTRIC': 1.0, 'GRASS': 0.5, 'POISON': 0.5, 'GROUND': 2.0, 'FLYING': 0.5, 'BUG': 0.5, 'ROCK': 2.0, 'DRAGON': 0.5},
    'ICE': {'WATER': 0.5, 'GRASS': 2.0, 'ICE': 0.5, 'GROUND': 2.0, 'FLYING': 2.0, 'DRAGON': 2.0},
    'FIGHTING': {'NORMAL': 2.0, 'POISON': 0.5, 'FLYING': 0.5, 'PSYCHIC': 0.5, 'BUG': 0.5, 'ROCK': 2.0, 'GHOST': 0.0},
    'POISON': {'GRASS': 2.0, 'POISON': 0.5, 'GROUND': 0.5, 'BUG': 2.0, 'ROCK': 0.5, 'GHOST': 0.5},
    'GROUND': {'FIRE': 2.0, 'ELECTRIC': 2.0, 'GRASS': 0.5, 'POISON': 2.0, 'FLYING': 0.0, 'BUG': 0.5, 'ROCK': 2.0},
    'FLYING': {'ELECTRIC': 0.5, 'GRASS': 2.0, 'FIGHTING': 2.0, 'BUG': 2.0, 'ROCK': 0.5},
    'PSYCHIC': {'FIGHTING': 2.0, 'POISON': 2.0, 'PSYCHIC': 0.5, 'GHOST': 1.0}, # In Gen 1, Psychic era immune a Ghost per un bug, ma i dati Showdown potrebbero averlo corretto. Assumiamo 1.0 per sicurezza, o 0.0 se il bug è emulato. Qui usiamo 1.0.
    'BUG': {'FIRE': 0.5, 'GRASS': 2.0, 'FIGHTING': 0.5, 'POISON': 2.0, 'FLYING': 0.5, 'PSYCHIC': 2.0},
    'ROCK': {'FIRE': 2.0, 'ICE': 2.0, 'FIGHTING': 0.5, 'GROUND': 0.5, 'FLYING': 2.0, 'BUG': 2.0},
    'GHOST': {'NORMAL': 0.0, 'PSYCHIC': 0.0, 'GHOST': 2.0}, # Famoso bug: Lick (Ghost) non colpisce Psychic.
    'DRAGON': {'DRAGON': 2.0},
}

# Funzione helper per calcolare l'efficacia
def get_type_effectiveness(move_type, target_types):
    if move_type not in TYPE_CHART_GEN1:
        return 1.0
    
    multiplier = 1.0
    chart_for_move = TYPE_CHART_GEN1[move_type]
    
    for target_type in target_types:
        if target_type in chart_for_move:
            multiplier *= chart_for_move[target_type]
            
    return multiplier

# Pokémon dominanti nel metagame Gen 1 OU (S-Tier e A-Tier)
# La loro presenza è un segnale fortissimo.
META_THREATS_GEN1 = {
    'Snorlax', 'Tauros', 'Chansey', 'Alakazam', 'Starmie', 'Exeggutor', 
    'Zapdos', 'Jolteon', 'Rhydon', 'Golem', 'Lapras'
}

# Mosse di setup o status chiave
STATUS_MOVES = {'Thunder Wave', 'Sleep Powder', 'Sing', 'Toxic', 'Lovely Kiss', 'Spore', 'Stun Spore', 'Glare'}
SETUP_MOVES = {'Amnesia', 'Swords Dance', 'Agility', 'Growth'}

# %%
def create_advanced_features_1(df):
    processed_data = []
    for _, row in tqdm(df.iterrows(), total=df.shape[0], desc="Creazione features"):
        p1_team = row['p1_team_details']
        p2_lead = row['p2_lead_details']
        timeline = row['battle_timeline']
        p1_lead = p1_team[0]
        
        feat_lead_speed_diff = p1_lead['base_spe'] - p2_lead['base_spe']
        
        p1_seen_status = {p['name']: {'hp_pct': 100, 'status': None} for p in p1_team}
        p2_seen_status = {p2_lead['name']: {'hp_pct': 100, 'status': None}}
        
        feat_end_boost_diff = 0
        feat_num_turns = 0
        
        if timeline:
            feat_num_turns = timeline[-1].get('turn', 0)
            for turn in timeline:
                p1_state = turn.get('p1_pokemon_state')
                if p1_state and p1_state.get('name'):
                    p1_name = p1_state['name']
                    p1_seen_status.setdefault(p1_name, {'hp_pct': 100, 'status': None})
                    p1_seen_status[p1_name]['hp_pct'] = p1_state.get('hp_pct', p1_seen_status[p1_name]['hp_pct'])
                    p1_seen_status[p1_name]['status'] = p1_state.get('status', p1_seen_status[p1_name]['status'])
                    
                p2_state = turn.get('p2_pokemon_state')
                if p2_state and p2_state.get('name'):
                    p2_name = p2_state['name']
                    p2_seen_status.setdefault(p2_name, {'hp_pct': 100, 'status': None})
                    p2_seen_status[p2_name]['hp_pct'] = p2_state.get('hp_pct', p2_seen_status[p2_name]['hp_pct'])
                    p2_seen_status[p2_name]['status'] = p2_state.get('status', p2_seen_status[p2_name]['status'])

                if turn.get('turn') == feat_num_turns:
                    p1_boosts = sum(p1_state.get('boosts', {}).values()) if p1_state else 0
                    p2_boosts = sum(p2_state.get('boosts', {}).values()) if p2_state else 0
                    feat_end_boost_diff = p1_boosts - p2_boosts

        p1_total_hp_seen = sum(p['hp_pct'] for p in p1_seen_status.values())
        p2_total_hp_seen = sum(p['hp_pct'] for p in p2_seen_status.values())
        feat_hp_advantage_seen = p1_total_hp_seen - p2_total_hp_seen
        
        feat_mons_revealed_diff = len(p2_seen_status) - len(p1_seen_status)
        
        p1_team_status_count = sum(1 for p in p1_seen_status.values() if p['status'] is not None)
        p2_team_status_count = sum(1 for p in p2_seen_status.values() if p['status'] is not None)
        feat_team_status_diff = p1_team_status_count - p2_team_status_count # (P1 status) - (P2 status)

        processed_data.append({
            'battle_id': row['battle_id'],
            'p1_lead_name': p1_lead['name'], 'p2_lead_name': p2_lead['name'],
            'lead_speed_diff': feat_lead_speed_diff,
            'hp_advantage_seen': feat_hp_advantage_seen,
            'mons_revealed_diff': feat_mons_revealed_diff,
            'team_status_diff': feat_team_status_diff,
            'end_boost_diff': feat_end_boost_diff,
            'num_turns': feat_num_turns
        })
    return pd.DataFrame(processed_data).set_index('battle_id')

# %%
print("Inizio feature engineering avanzata sul set di training...")
X_train_features = create_advanced_features_1(train_df)

print("\nInizio feature engineering avanzata sul set di test...")
X_test_features = create_advanced_features_1(test_df)

# Definiamo la nostra variabile target 'y'
y_train = train_df.set_index('battle_id')['player_won']

# Allineiamo X e y
y_train = y_train.loc[X_train_features.index]

print("\nFeature engineering completato. Esempio di dati trasformati:")
print(X_train_features.head())
# Out:
# Inizio feature engineering avanzata sul set di training...
# Creazione features:   0%|          | 0/9996 [00:00<?, ?it/s]
# Inizio feature engineering avanzata sul set di test...
# Creazione features:   0%|          | 0/5000 [00:00<?, ?it/s]
# Feature engineering completato. Esempio di dati trasformati:
#           p1_lead_name p2_lead_name  lead_speed_diff  hp_advantage_seen  \
# battle_id
# 0              starmie      starmie                0         201.225312
# 1                 jynx     alakazam              -25          -0.990000
# 2            exeggutor      chansey                5         299.020000
# 3               gengar       tauros                0         100.180000
# 4             alakazam      starmie                5         100.610000
#
#            mons_revealed_diff  team_status_diff  end_boost_diff  num_turns
# battle_id
# 0                          -2                 0               0         30
# 1                           0                 0               2         30
# 2                          -2                -1               0         30
# 3                          -2                 1               0         30
# 4                          -1                 0               0         30

# %%
numeric_features = [
    'lead_speed_diff',
    'hp_advantage_seen',
    'mons_revealed_diff',
    'team_status_diff',
    'end_boost_diff',
    'num_turns'
]
categorical_features = ['p1_lead_name', 'p2_lead_name']

# Creiamo i trasformatori (StandardScaler e OneHotEncoder)
numeric_transformer = Pipeline(steps=[('scaler', RobustScaler())])
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ],
    remainder='passthrough'
)

# %%
# Dividiamo i dati di training per una validazione locale
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train_features, 
    y_train, 
    test_size=0.2, # 20% per la validazione
    random_state=42,
    stratify=y_train # Mantiene l'equilibrio delle classi
)

print(f"Dimensione Training Split: {X_train_split.shape}")
print(f"Dimensione Validation Split: {X_val_split.shape}")

# 1. Creiamo la pipeline con un modello "di default"
# Usiamo C=1.0 come valore predefinito
baseline_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(random_state=42, max_iter=1000, solver='liblinear', C=1.0))
])

# 2. Alleniamo il modello base SUL SOLO SET DI TRAINING SPLIT
print("\nAllenamento del modello baseline...")
baseline_pipeline.fit(X_train_split, y_train_split)

# 3. Valutiamo il modello base SUL SET DI VALIDAZIONE
y_val_pred = baseline_pipeline.predict(X_val_split)
val_accuracy = accuracy_score(y_val_split, y_val_pred)

print(f"\n--- Risultati Modello Baseline ---")
print(f"Accuracy sul Validation Set: {val_accuracy:.4f}")
print("---------------------------------")
# Out:
# Dimensione Training Split: (7996, 8)
# Dimensione Validation Split: (2000, 8)
#
# Allenamento del modello baseline...
#
# --- Risultati Modello Baseline ---
# Accuracy sul Validation Set: 0.7390
# ---------------------------------

# %%
from sklearn.model_selection import GridSearchCV
print("\nAvvio di GridSearchCV per l'ottimizzazione degli iperparametri...")
# 1. Creiamo la pipeline (la stessa di prima, ma senza 'C' definito)
# La pipeline che verrà testata da GridSearchCV
tuning_pipeline_reg = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(random_state=42, max_iter=1000, solver='liblinear'))
])

# 2. Definiamo la griglia dei parametri
# Vogliamo testare diversi valori per 'classifier__C'
param_grid = {
    'classifier__penalty': ['l1', 'l2'], 
    'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100],
    'classifier__solver': ['liblinear'] 
}

# 3. Impostiamo GridSearchCV
# cv=5 significa 5-fold cross-validation
# scoring='accuracy' è la nostra metrica
# n_jobs=-1 usa tutti i processori
grid_search = GridSearchCV(
    tuning_pipeline_reg, 
    param_grid, 
    cv=10, 
    scoring='accuracy', 
    n_jobs=-1,
    verbose=1 # Mostra i log
)

# 4. Avviamo la ricerca sull'INTERO set di training
# (GridSearchCV gestirà internamente le divisioni di cross-validation)
grid_search.fit(X_train_features, y_train)

# 5. Analizziamo i risultati
print("\n--- Risultati GridSearchCV ---")
print(f"Migliori parametri trovati: {grid_search.best_params_}")
print(f"Migliore Accuracy (media CV): {grid_search.best_score_:.4f}")
print("------------------------------")
# Out:
# Avvio di GridSearchCV per l'ottimizzazione degli iperparametri...
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#
# --- Risultati GridSearchCV ---
# Migliori parametri trovati: {'classifier__C': 10, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# Migliore Accuracy (media CV): 0.8276
# ------------------------------

# %%
# 1. Il nostro modello finale è il 'best_estimator_' trovato da GridSearch
final_model = grid_search.best_estimator_

print("\nGenerazione delle predizioni sul set di test...")
# 2. Usiamo il modello finale per predire sul set di test (X_test_features)
test_predictions = final_model.predict(X_test_features)

# Ignoriamo i warning per pulizia
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# --- FASE 1: VALIDAZIONE ---

# Dividi i dati di training per la validazione
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train_features, y_train, test_size=0.20, random_state=42, stratify=y_train
)

# Allena un modello base (es. 'baseline_pipeline') sulla parte splittata
baseline_pipeline.fit(X_train_split, y_train_split)

# Calcola l'accuracy sul set di validazione
y_val_pred = baseline_pipeline.predict(X_val_split)
val_accuracy = accuracy_score(y_val_split, y_val_pred)

print(f"--- Accuracy di Validazione (stima): {val_accuracy * 100:.2f}% ---")

# -----------------------------------------------------------------

# --- FASE 2: ALLENAMENTO DEL MODELLO OTTIMIZZATO ---

# Allena il GridSearchCV su TUTTI i dati di training
# (Questo è il 'grid_search' definito nel Passaggio 6 della risposta precedente)
grid_search.fit(X_train_features, y_train)

print(f"\n--- Risultati GridSearchCV ---")
print(f"Migliori parametri trovati: {grid_search.best_params_}")
print(f"Migliore Accuracy (media CV): {grid_search.best_score_:.4f}")

# 1. Il tuo modello finale e ottimizzato è pronto
final_model = grid_search.best_estimator_
cv_accuracy = grid_search.best_score_

# 2. Usa il tuo modello finale (ottimizzato) per fare previsioni
#    sul set di validazione (X_val_split)
y_val_pred = final_model.predict(X_val_split)

# 3. Calcola l'accuracy confrontando le previsioni (y_val_pred)
#    con le risposte vere (y_val_split)
final_model_accuracy = accuracy_score(y_val_split, y_val_pred)

print(f"Accuracy del 'final_model' sul set di validazione: {final_model_accuracy * 100:.2f}%")

print(f"Accuracy (media da Cross-Validation): {cv_accuracy * 100:.2f}%")
# Out:
# Generazione delle predizioni sul set di test...
# --- Accuracy di Validazione (stima): 73.90% ---
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
#
# --- Risultati GridSearchCV ---
# Migliori parametri trovati: {'classifier__C': 10, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# Migliore Accuracy (media CV): 0.8276
# Accuracy del 'final_model' sul set di validazione: 82.75%
# Accuracy (media da Cross-Validation): 82.76%

# %%
import pandas as pd

# 1. Estrai il modello migliore (la pipeline completa) da GridSearchCV
final_model = grid_search.best_estimator_

# 2. Estrai i nomi delle feature numeriche (li abbiamo già)
# Assicurati che 'numeric_features' sia la lista aggiornata che hai usato
# numeric_features = ['lead_speed_diff', 'p1_lead_type_adv', ...]

# 3. Estrai i nomi delle feature categoriche create dal OneHotEncoder
# Questo è il passaggio chiave
try:
    categorical_names = final_model.named_steps['preprocessor'] \
                                     .named_transformers_['cat'] \
                                     .named_steps['onehot'] \
                                     .get_feature_names_out(categorical_features)
except AttributeError:
    # Fallback per versioni più vecchie di scikit-learn
    categorical_names = final_model.named_steps['preprocessor'] \
                                     .named_transformers_['cat'] \
                                     .named_steps['onehot'] \
                                     .get_feature_names_out()

# 4. Combina tutti i nomi delle feature nell'ordine corretto
all_feature_names = numeric_features + list(categorical_names)

# 5. Estrai i coefficienti (l'importanza) dal modello di regressione logistica
coefficients = final_model.named_steps['classifier'].coef_[0]

# 6. Crea un DataFrame per visualizzarli in modo chiaro
importance_df = pd.DataFrame({
    'Feature': all_feature_names,
    'Coefficient': coefficients
})

# 7. Aggiungi il 'Coefficiente Assoluto' per ordinare per impatto (sia positivo che negativo)
importance_df['Impact'] = importance_df['Coefficient'].abs()
importance_df = importance_df.sort_values(by='Impact', ascending=False)

# 8. Stampa i risultati
print("--- Importanza delle Feature (Coefficienti del Modello) ---")
print(importance_df.to_string()) # .to_string() stampa tutto il DataFrame senza troncamenti
# Out:
# --- Importanza delle Feature (Coefficienti del Modello) ---
#                     Feature  Coefficient      Impact
# 3          team_status_diff   237.184905  237.184905
# 1         hp_advantage_seen   121.573285  121.573285
# 2        mons_revealed_diff   120.600679  120.600679
# 7     p1_lead_name_articuno    -1.406076    1.406076
# 38     p2_lead_name_persian     1.211139    1.211139
# 34       p2_lead_name_golem     1.122647    1.122647
# 40     p2_lead_name_slowbro    -1.110449    1.110449
# 11   p1_lead_name_dragonite     0.992378    0.992378
# 10    p1_lead_name_cloyster    -0.954911    0.954911
# 24  p1_lead_name_victreebel    -0.906475    0.906475
# 37      p2_lead_name_lapras    -0.847103    0.847103
# 15     p1_lead_name_jolteon    -0.629374    0.629374
# 18     p1_lead_name_persian     0.552479    0.552479
# 30    p2_lead_name_cloyster     0.547183    0.547183
# 8      p1_lead_name_chansey    -0.480437    0.480437
# 39      p2_lead_name_rhydon    -0.457819    0.457819
# 45      p2_lead_name_zapdos    -0.432020    0.432020
# 36        p2_lead_name_jynx    -0.399845    0.399845
# 42     p2_lead_name_starmie    -0.363721    0.363721
# 20     p1_lead_name_slowbro     0.347283    0.347283
# 44  p2_lead_name_victreebel     0.290226    0.290226
# 32   p2_lead_name_exeggutor    -0.267625    0.267625
# 43      p2_lead_name_tauros     0.252211    0.252211
# 14       p1_lead_name_golem     0.248555    0.248555
# 21     p1_lead_name_snorlax    -0.220796    0.220796
# 0           lead_speed_diff     0.184929    0.184929
# 12   p1_lead_name_exeggutor     0.179345    0.179345
# 26    p2_lead_name_alakazam    -0.177620    0.177620
# 28     p2_lead_name_chansey     0.165045    0.165045
# 23      p1_lead_name_tauros    -0.149347    0.149347
# 19      p1_lead_name_rhydon    -0.138572    0.138572
# 17      p1_lead_name_lapras     0.118020    0.118020
# 16        p1_lead_name_jynx     0.113434    0.113434
# 6     p1_lead_name_alakazam    -0.096987    0.096987
# 33      p2_lead_name_gengar    -0.079416    0.079416
# 22     p1_lead_name_starmie     0.062547    0.062547
# 4            end_boost_diff     0.061508    0.061508
# 13      p1_lead_name_gengar    -0.009638    0.009638
# 41     p2_lead_name_snorlax     0.003024    0.003024
# 25      p1_lead_name_zapdos     0.000000    0.000000
# 31   p2_lead_name_dragonite     0.000000    0.000000
# 35     p2_lead_name_jolteon     0.000000    0.000000
# 27    p2_lead_name_articuno     0.000000    0.000000
# 29   p2_lead_name_charizard     0.000000    0.000000
# 9    p1_lead_name_charizard     0.000000    0.000000
# 5                 num_turns     0.000000    0.000000

# %%
# 1. Estrai il modello finale
final_model = grid_search.best_estimator_

# 2. Genera le predizioni (saranno True/False)
test_predictions_bool = final_model.predict(X_test_features)

# 3. --- CORREZIONE 1: Converti True/False in 1/0 ---
# .astype(int) converte True -> 1 e False -> 0
test_predictions_int = test_predictions_bool.astype(int)

# 4. Prendi i battle_id dall'indice
test_battle_ids = X_test_features.index

# 5. Crea il DataFrame con le due colonne CORRETTE
submission_df = pd.DataFrame({
    'battle_id': test_battle_ids,
    'player_won': test_predictions_int  # Usa la versione 1/0
})

# 6. --- CORREZIONE 2: Salva SENZA l'indice di pandas ---
# Aggiungendo 'index=False' si risolve il problema della "stessa colonna".
submission_df.to_csv('submission_predictions.csv', index=False)

print("\n-------------------------------------------------")
print("File 'submission_predictions.csv' creato con successo!")
print("Ora conterrà 1 e 0, e colonne separate.")
print("-------------------------------------------------")

# Stampa un'anteprima
print(submission_df.head())
# Out:
# -------------------------------------------------
# File 'submission_predictions.csv' creato con successo!
# Ora conterrà 1 e 0, e colonne separate.
# -------------------------------------------------
#    battle_id  player_won
# 0          0           0
# 1          1           1
# 2          2           1
# 3          3           1
# 4          4           1

# %%
# --- 4. Funzione Feature Engineering ("Full Story") ---
print("🧠 Inizio feature engineering (Strategia 'Full Story')...")

def create_advanced_features_2(df):
    
    processed_data = []
    
    useless_leads = {
        'Articuno', 'Golem', 'Rhydon', 'Lapras', 'Cloyster', 
        'Charizard', 'Victreebel', 'Dragonite', 'Gengar', 'Persian' 
    }
    
    for _, row in tqdm(df.iterrows(), total=df.shape[0], desc="Analisi 'Full Story'"):
        
        p1_team = row['p1_team_details']
        p2_lead = row['p2_lead_details']
        timeline = row['battle_timeline']
        p1_lead = p1_team[0]
        
        p1_lead_name = p1_lead['name'] if p1_lead['name'] not in useless_leads else 'Other'
        p2_lead_name = p2_lead['name'] if p2_lead['name'] not in useless_leads else 'Other'
            
        # --- Feature Statiche (Turno 0) ---
        feat_lead_speed_diff = p1_lead['base_spe'] - p2_lead['base_spe']
        feat_p1_team_avg_speed = np.mean([p.get('base_spe', 70) for p in p1_team])
        feat_p1_team_avg_bulk = np.mean([(p.get('base_hp', 80) + p.get('base_def', 80) + p.get('base_spa', 80)) for p in p1_team])
        feat_p1_meta_threat_count = sum(1 for p in p1_team if p.get('name') in META_THREATS_GEN1)
        feat_p2_lead_is_meta_threat = 1 if p2_lead['name'] in META_THREATS_GEN1 else 0
        
        # --- Feature Dinamiche (Turno 1-30) ---
        p1_seen_status = {p['name']: {'hp_pct': 100, 'status': None} for p in p1_team}
        p2_seen_status = {p2_lead['name']: {'hp_pct': 100, 'status': None}}
        feat_end_boost_diff = 0
        feat_p1_lead_stay_duration = 0
        feat_p2_lead_forced_out = 0
        feat_first_ko_turn = 0
        feat_p1_setup_moves = 0
        feat_p2_setup_moves = 0
        
        if timeline:
            feat_num_turns = timeline[-1].get('turn', 0)
            first_ko_achieved = False
            last_p2_mon_name = p2_lead['name']
            
            for i, turn in enumerate(timeline):
                p1_state = turn.get('p1_pokemon_state', {})
                p2_state = turn.get('p2_pokemon_state', {})
                p1_move = turn.get('p1_move_details')
                p2_move = turn.get('p2_move_details')
                
                # Tracciamento HP/Status (con bug corretto)
                if p1_state and p1_state.get('name'):
                    p1_name = p1_state['name']
                    p1_seen_status.setdefault(p1_name, {'hp_pct': 100, 'status': None})
                    if p1_state.get('hp_pct') is not None:
                        p1_seen_status[p1_name]['hp_pct'] = p1_state.get('hp_pct')
                    p1_seen_status[p1_name]['status'] = p1_state.get('status')
                if p2_state and p2_state.get('name'):
                    p2_name = p2_state['name']
                    p2_seen_status.setdefault(p2_name, {'hp_pct': 100, 'status': None})
                    if p2_state.get('hp_pct') is not None:
                        p2_seen_status[p2_name]['hp_pct'] = p2_state.get('hp_pct')
                    p2_seen_status[p2_name]['status'] = p2_state.get('status')
                
                # Boost (solo ultimo turno)
                if turn.get('turn') == feat_num_turns:
                    feat_end_boost_diff = sum(p1_state.get('boosts', {}).values()) - sum(p2_state.get('boosts', {}).values())
                
                # Tracciamento Durata Lead P1
                if p1_state.get('name') == p1_lead['name']:
                    feat_p1_lead_stay_duration += 1
                
                # Tracciamento P2 Lead Forzato a Uscire
                if i > 0 and p2_state.get('name') != last_p2_mon_name and last_p2_mon_name == p2_lead['name']:
                    feat_p2_lead_forced_out = 1
                if p2_state.get('name') != last_p2_mon_name:
                    last_p2_mon_name = p2_state.get('name')
                
                # Tracciamento Primo KO
                if not first_ko_achieved and (p1_state.get('hp_pct') == 0 or p2_state.get('hp_pct') == 0):
                    feat_first_ko_turn = turn.get('turn', 0)
                    first_ko_achieved = True
                
                # Tracciamento Setup Moves
                if p1_move and p1_move.get('name') in SETUP_MOVES:
                    feat_p1_setup_moves += 1
                if p2_move and p2_move.get('name') in SETUP_MOVES:
                    feat_p2_setup_moves += 1

        feat_setup_advantage = feat_p1_setup_moves - feat_p2_setup_moves

        # Feature "Risultato Turno 30" (le tue migliori)
        p1_total_hp_seen = sum(p['hp_pct'] for p in p1_seen_status.values())
        p2_total_hp_seen = sum(p['hp_pct'] for p in p2_seen_status.values())
        feat_hp_advantage_seen = p1_total_hp_seen - p2_total_hp_seen
        feat_mons_revealed_diff = len(p2_seen_status) - len(p1_seen_status)
        
        def calculate_status_score(status_dict):
            score = 0
            for p in status_dict.values():
                status = p.get('status')
                if status == 'slp': score += 3
                elif status == 'par': score += 2
                elif status in ['psn', 'tox']: score += 1
            return score
        p1_team_status_score = calculate_status_score(p1_seen_status)
        p2_team_status_score = calculate_status_score(p2_seen_status)
        feat_weighted_status_diff = p1_team_status_score - p2_team_status_score

        processed_data.append({
            'battle_id': row['battle_id'],
            'p1_lead_name': p1_lead_name, 
            'p2_lead_name': p2_lead_name,
            
            # Statiche (Turno 0)
            'lead_speed_diff': feat_lead_speed_diff,
            'p1_team_avg_speed': feat_p1_team_avg_speed,
            'p1_team_avg_bulk': feat_p1_team_avg_bulk,
            'p1_meta_threat_count': feat_p1_meta_threat_count,
            'p2_lead_is_meta_threat': feat_p2_lead_is_meta_threat,
            
            # Dinamiche "Tempo" (Turno 1-30)
            'p1_lead_stay_duration': feat_p1_lead_stay_duration,
            'p2_lead_forced_out': feat_p2_lead_forced_out,
            'first_ko_turn': feat_first_ko_turn,
            'setup_advantage': feat_setup_advantage,
            
            # Dinamiche "Risultato" (Turno 30)
            'hp_advantage_seen': feat_hp_advantage_seen,
            'mons_revealed_diff': feat_mons_revealed_diff,
            'weighted_status_diff': feat_weighted_status_diff,
            'end_boost_diff': feat_end_boost_diff,
        })
    return pd.DataFrame(processed_data).set_index('battle_id')

# Esegui la creazione delle feature
X_train_features = create_advanced_features_2(train_df)
X_test_features = create_advanced_features_2(test_df)
y_train = train_df.set_index('battle_id')['player_won'].loc[X_train_features.index]
print("Feature engineering ('Full Story') completato.")

# --- 5. Definizione Liste Feature (TUTTE) ---
numeric_features = [
    # Statiche
    'lead_speed_diff',
    'p1_team_avg_speed',
    'p1_team_avg_bulk',
    'p1_meta_threat_count',
    'p2_lead_is_meta_threat',
    
    # Dinamiche "Tempo"
    'p1_lead_stay_duration',
    'p2_lead_forced_out',
    'first_ko_turn',
    'setup_advantage',
    
    # Dinamiche "Risultato"
    'hp_advantage_seen',
    'mons_revealed_diff',
    'weighted_status_diff',
    'end_boost_diff',
]
categorical_features = ['p1_lead_name', 'p2_lead_name']

# --- 6. Creazione Pipeline (per XGBoost) ---
print("🛠️  Costruzione pipeline XGBoost...")

numeric_transformer = Pipeline(steps=[('scaler', 'passthrough')]) 
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ],
    remainder='passthrough'
)

tuning_pipeline_xgb = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', XGBClassifier(random_state=42, eval_metric='logloss')) 
])

# --- 7. PARAM_GRID (Ottimizzazione Avanzata) --- {'classifier__colsample_bytree': 0.8, 'classifier__gamma': 0.1,
# 'classifier__learning_rate': 0.05, 'classifier__max_depth': 4, 'classifier__n_estimators': 500, 'classifier__subsample': 0.7}
#{'classifier__colsample_bytree': 0.9, 'classifier__gamma': 0.2, 'classifier__learning_rate': 0.03, 'classifier__max_depth': 5,
 #'classifier__n_estimators': 600, 'classifier__subsample': 0.8}
print("⚙️ Definizione della griglia di iperparametri avanzata...")
param_grid = {
    'classifier__n_estimators': [600, 700],
    'classifier__learning_rate': [0.02, 0.03, 0.04],
    'classifier__max_depth': [3, 4, 5], # Manteniamo la profondità bassa per evitare overfitting
    'classifier__subsample': [0.7, 0.8, 0.9],
    'classifier__colsample_bytree': [ 0.8, 0.9],
    'classifier__gamma': [ 0.2, 0.3] # Regolarizzazione più forte
}

# --- 8. Addestramento GridSearchCV ---
print("🚀 Inizio addestramento (GridSearchCV 'Full Story')...")
print("⚠️ Questo richiederà molto tempo!")

grid_search = GridSearchCV(
    tuning_pipeline_xgb, 
    param_grid, 
    cv=5, 
    scoring='accuracy', 
    n_jobs=-1,
    verbose=2
)
grid_search.fit(X_train_features, y_train)

print("\n--- ✅ Risultati Finali ---")
print(f"Migliori parametri trovati: {grid_search.best_params_}")
print(f"Accuracy FINALE (media CV): {grid_search.best_score_ * 100:.2f}%")
# --- 9. Creazione File CSV Finale (submission_predictions.csv) ---
print("\n📄 Creazione file 'submission_predictions.csv'...")

final_model = grid_search.best_estimator_
test_predictions = final_model.predict(X_test_features)
test_battle_ids = X_test_features.index

submission_df = pd.DataFrame({
    'battle_id': test_battle_ids,
    'player_won': test_predictions.astype(int)
})

submission_df.to_csv('submission_predictions.csv', index=False)

print("-------------------------------------------------")
print("File 'submission_predictions.csv' creato con successo!")
print("Lo troverai nel pannello 'Data' -> 'Output' sulla destra.")
print("-------------------------------------------------")
print("\nAnteprima del file:")
print(submission_df.head())
# Out:
# 🧠 Inizio feature engineering (Strategia 'Full Story')...
# Analisi 'Full Story':   0%|          | 0/9996 [00:00<?, ?it/s]
# Analisi 'Full Story':   0%|          | 0/5000 [00:00<?, ?it/s]
# Feature engineering ('Full Story') completato.
# 🛠️  Costruzione pipeline XGBoost...
# ⚙️ Definizione della griglia di iperparametri di FASE 2...
# 🚀 Inizio addestramento (RandomizedSearchCV 'Full Story')...
# ⚠️ Questo richiederà un po' di tempo, ma molto meno di GridSearchCV!
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.7s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.0s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   2.7s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=700, classifier__subsample=0.8; total time=   1.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.4s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.3s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   3.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.9s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   3.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.7s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=1.0; total time=   1.9s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=1.0; total time=   1.9s[CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.9s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   2.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=700, classifier__subsample=0.8; total time=   1.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=700, classifier__subsample=0.8; total time=   1.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.4s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.5s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   3.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   2.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.0s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.9s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.7s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.9s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.9s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=1.0; total time=   1.9s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.6s[CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   2.3s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.0s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.0s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.5s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=700, classifier__subsample=0.8; total time=   1.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.4s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.5s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   2.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.9s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.9s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   3.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.0s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.9s[CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   2.7s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.4s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.4s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=700, classifier__subsample=0.8; total time=   1.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.4s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.5s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   3.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.9s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.7s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=1.0; total time=   1.9s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=1.0; total time=   1.9s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.0s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=1.0; total time=   1.9s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=1.0; total time=   1.9s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.0s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.5s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.4s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   3.4s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=0.9; total time=   1.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.9; total time=   1.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=1.0; total time=   1.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=1.0; total time=   1.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=1.0; total time=   1.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.9; total time=   2.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.0s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.0s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.0s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   1.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   1.8s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   1.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.5s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.1s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   3.4s
# ...
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   1.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.4s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.4s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.4s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.5s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.3s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=700, classifier__subsample=1.0; total time=   1.5s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.0s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   1.9s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   1.9s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   1.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.7s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   3.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   3.2s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   3.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.7, classifier__gamma=0.1, classifier__learning_rate=0.02, classifier__max_depth=3, classifier__n_estimators=500, classifier__subsample=0.6; total time=   1.0s
# [CV] END classifier__colsample_bytree=0.7, classifier__gamma=0.1, classifier__learning_rate=0.02, classifier__max_depth=3, classifier__n_estimators=500, classifier__subsample=0.7; total time=   1.0s
# [CV] END classifier__colsample_bytree=0.7, classifier__gamma=0.1, classifier__learning_rate=0.02, classifier__max_depth=3, classifier__n_estimators=500, classifier__subsample=0.7; total time=   1.0s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=700, classifier__subsample=1.0; total time=   1.5s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=700, classifier__subsample=1.0; total time=   1.5s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.5s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=0.8; total time=   3.7s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   3.3s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=4, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.2s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.01, classifier__max_depth=4, classifier__n_estimators=700, classifier__subsample=0.8; total time=   1.8s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   4.1s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   4.0s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.4s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.9; total time=   2.3s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.4s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.01, classifier__max_depth=5, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.3s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=6, classifier__n_estimators=700, classifier__subsample=0.8; total time=   2.4s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.0s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   3.0s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=1.0; total time=   2.3s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.2s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=1.0; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1000, classifier__subsample=0.9; total time=   2.6s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=700, classifier__subsample=1.0; total time=   1.5s
# [CV] END classifier__colsample_bytree=0.8, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   3.3s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.03, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   1.8s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.4, classifier__learning_rate=0.03, classifier__max_depth=4, classifier__n_estimators=1200, classifier__subsample=0.9; total time=   2.7s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   2.5s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=5, classifier__n_estimators=700, classifier__subsample=1.0; total time=   1.9s
# [CV] END classifier__colsample_bytree=0.9, classifier__gamma=0.4, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=800, classifier__subsample=0.8; total time=   2.6s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.2, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1000, classifier__subsample=1.0; total time=   3.1s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   4.0s
# [CV] END classifier__colsample_bytree=1.0, classifier__gamma=0.3, classifier__learning_rate=0.02, classifier__max_depth=6, classifier__n_estimators=1200, classifier__subsample=0.8; total time=   4.9s
# [CV] END classifier__colsample_bytree=0.7, classifier__gamma=0.1, classifier__learning_rate=0.02, classifier__max_depth=3, classifier__n_estimators=500, classifier__subsample=0.6; total time=   1.0s
# [CV] END classifier__colsample_bytree=0.7, classifier__gamma=0.1, classifier__learning_rate=0.02, classifier__max_depth=3, classifier__n_estimators=500, classifier__subsample=0.6; total time=   1.0s
# [CV] END classifier__colsample_bytree=0.7, classifier__gamma=0.1, classifier__learning_rate=0.02, classifier__max_depth=3, classifier__n_estimators=500, classifier__subsample=0.7; total time=   1.1s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_48/56482212.py in <cell line: 0>()
#     246     verbose=2
#     247 )
# --> 248 grid_search.fit(X_train_features, y_train)
#     249
#     250 print("\n--- ✅ Risultati Finali ---")
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    2070         next(output)
#    2071
# -> 2072         return output if self.return_generator else list(output)
#    2073
#    2074     def __repr__(self):
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1680
#    1681             with self._backend.retrieval_context():
# -> 1682                 yield from self._retrieve()
#    1683
#    1684         except GeneratorExit:
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _retrieve(self)
#    1798                     self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799                 ):
# -> 1800                     time.sleep(0.01)
#    1801                     continue
#    1802
#
# KeyboardInterrupt:

# %%
# --- 2. Creazione Pipeline (per Stacking) ---
print("🛠️  Costruzione pipeline Stacking...")

# --- Pipeline 1: XGBoost (Modello non lineare) ---
# Usa il pre-processore che non standardizza ('passthrough')
preprocessor_xgb = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features)
    ],
    remainder='passthrough'
)
# Usa i parametri migliori che hai trovato per 83.95% #{'classifier__colsample_bytree': 0.9, 'classifier__gamma': 0.2, 'classifier__learning_rate': 0.03, 'classifier__max_depth': 5,
 #'classifier__n_estimators': 600, 'classifier__subsample': 0.8}
#{'classifier__colsample_bytree': 1, 'classifier__gamma': 0.3, 'classifier__learning_rate': 0.02, 'classifier__max_depth': 5, 'classifier__n_estimators': 700, 'classifier__subsample': 0.9}
#{'classifier__subsample': 0.9, 'classifier__n_estimators': 700, 'classifier__max_depth': 5, 'classifier__learning_rate': 0.02, 
#'classifier__gamma': 0.3, 'classifier__colsample_bytree': 0.9}
clf_xgb = XGBClassifier(random_state=42, 
                        eval_metric='logloss',
                        n_estimators=600,
                        learning_rate=0.03,
                        max_depth=5,
                        subsample=0.8,
                        colsample_bytree=0.9,
                        gamma=0.2)
pipeline_xgb = Pipeline(steps=[('preprocessor', preprocessor_xgb),
                               ('classifier', clf_xgb)])

# --- Pipeline 2: Logistic Regression (Modello lineare) ---
# DEVE usare StandardScaler
numeric_transformer_logreg = Pipeline(steps=[('scaler', StandardScaler())])
categorical_transformer_logreg = Pipeline(steps=[('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))])
preprocessor_logreg = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer_logreg, numeric_features),
        ('cat', categorical_transformer_logreg, categorical_features)
    ],
    remainder='passthrough'
)
# Usa i parametri migliori che hai trovato per il 73%{'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
clf_logreg = LogisticRegression(C=10, solver='liblinear', random_state=42, penalty='l1') 
pipeline_logreg = Pipeline(steps=[('preprocessor', preprocessor_logreg),
                                  ('classifier', clf_logreg)])

# --- Livello Finale: Stacking (Il "Meta-Modello") ---
print("🧠 Creazione del Meta-Modello...")
# Creiamo il "Meta-Modello" (Il Capo)
meta_model = LogisticRegression(C=1.0, random_state=42)

# Creiamo il modello Stacked
stacking_clf = StackingClassifier(
    estimators=[
        ('xgb', pipeline_xgb), 
        ('logreg', pipeline_logreg) # Combina i due modelli DIVERSI
    ], 
    final_estimator=meta_model, # Questo è il tuo "Meta-Modello"
    passthrough=False, # Diamo al "Capo" solo le previsioni (corregge l'errore 'starmie')
    cv=5,              # Cruciale per un addestramento robusto
    n_jobs=-1,
    verbose=1
)

# --- 3. Calcolo dell'Accuracy (Cross-Validation) ---
print("🚀 Avvio della Cross-Validation per il Meta-Modello...")
print("Questo richiederà MOLTO tempo...")

scores = cross_val_score(
    stacking_clf,                
    X_train_features,     
    y_train,              
    cv=5,                 
    scoring='accuracy',
    n_jobs=-1
)

print("\n--- ✅ Risultati della Cross-Validation ---")
print(f"Accuratezza per ognuno dei 5 test: {scores}")
print(f"Accuracy MEDIA FINALE: {scores.mean() * 100:.2f}%")
print(f"Deviazione Standard: {scores.std() * 100:.2f}%")


# --- 4. Addestramento Finale (per la Submission) ---
print("\n🚀 Inizio addestramento finale (Meta-Modello) sull'intero set di training...")
stacking_clf.fit(X_train_features, y_train)
print("Addestramento completato.")

# --- 5. Creazione File CSV Finale (submission_predictions.csv) ---
print("\n📄 Creazione file 'submission_predictions.csv'...")

final_model = stacking_clf # Il Meta-Modello è il modello finale
test_predictions = final_model.predict(X_test_features)
test_battle_ids = X_test_features.index

submission_df = pd.DataFrame({
    'battle_id': test_battle_ids,
    'player_won': test_predictions.astype(int)
})

submission_df.to_csv('submission_predictions.csv', index=False)

print("-------------------------------------------------")
print("File 'submission_predictions.csv' creato con successo!")
print("Lo troverai nel pannello 'Data' -> 'Output' sulla destra.")
print("-------------------------------------------------")
print("\nAnteprima del file:")
print(submission_df.head())
# Out:
# 🛠️  Costruzione pipeline Stacking...
# 🧠 Creazione del Meta-Modello...
# 🚀 Avvio della Cross-Validation per il Meta-Modello...
# Questo richiederà MOLTO tempo...
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.5s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.7s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.6s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    8.0s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    8.0s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    8.1s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    8.1s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.3s finished
# --- ✅ Risultati della Cross-Validation ---
# Accuratezza per ognuno dei 5 test: [0.8435     0.85042521 0.83791896 0.83291646 0.84642321]
# Accuracy MEDIA FINALE: 84.22%
# Deviazione Standard: 0.62%
#
# 🚀 Inizio addestramento finale (Meta-Modello) sull'intero set di training...
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.6s finished
# Addestramento completato.
#
# 📄 Creazione file 'submission_predictions.csv'...
# -------------------------------------------------
# File 'submission_predictions.csv' creato con successo!
# Lo troverai nel pannello 'Data' -> 'Output' sulla destra.
# -------------------------------------------------
#
# Anteprima del file:
#    battle_id  player_won
# 0          0           0
# 1          1           1
# 2          2           1
# 3          3           1
# 4          4           1
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.9s finished
