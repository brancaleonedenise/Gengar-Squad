# %%
features = [
    'lead_speed_diff',
    'hp_advantage_seen','mons_revealed_diff','team_status_diff','end_boost_diff',
    'total_damage_dealt','total_healing_done','status_turns',
    'first_faint_turn','total_stats_diff','damage_diff_turn10',
    'damage_diff_turn20','damage_diff_turn25','damage_diff_turn30',
    'hp_trend_diff','feat_switch_diff','feat_aggression_diff','hp_diff_std',
    'hp_diff_range','momentum_shift_turn','comeback_score','early_sustain',
    'status_balance','boost_volatility','boost_trend','move_power_diff',
    'move_diversity_diff','stall_ratio','aggression_index',
    'stats_speed_interaction',
    'hp_vs_stats_ratio','damage_ratio_turn25_30','damage_ratio_turn20_25',
    'damage_ratio_turn10_20','damage_ratio_turn10_30',
    'atk_def_ratio_p1','atk_def_ratio_p2','hp_speed_interaction_lead','hp_def_ratio_p1',
    'hp_def_ratio_p2','p1_hp_mean','p2_hp_mean','hp_diff_mean','hp_diff_last',
    'p1_boost_mean','p2_boost_mean','boost_diff_mean','p1_status_total',
    'p2_status_total','momentum_flips','p1_aggression','p2_aggression',
    'aggression_diff','feat_team_emb_sim',
    'lead_type_adv','meta_diff','feat_status_diff_inflicted','status_setup_diff',
    
]

# %%
from main import load_data
from Features.features_olya import create_advanced_features_gen2
import os
import pandas as pd
from utils.load_json import load_jsonl
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

test_size=0.2
random_state=42
train_df, test_df = load_data()



fraction_to_use = 1.0
train_df_subset = train_df.sample(frac=fraction_to_use, random_state=42).reset_index(drop=True)
test_df_subset = test_df.sample(frac=fraction_to_use, random_state=42).reset_index(drop=True)

# Feature engineering
X_train_features = create_advanced_features_gen2(train_df_subset)
X_test_features = create_advanced_features_gen2(test_df_subset)

# Target
y_train = train_df_subset.set_index('battle_id')['player_won']
y_test = test_df_subset.set_index('battle_id')

# Train/val split
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train_features,
    y_train,
    test_size=test_size,
    random_state=random_state,
    stratify=y_train
)

print("Shapes:")
print(X_train_split.shape, X_val_split.shape, y_train_split.shape, y_val_split.shape)
# Out:
# ✓ Local environment detected. Loading data from: Data
# ✓ train.jsonl loaded successfully. Shape: (10000, 5)
# ✓ test.jsonl loaded successfully. Shape: (5000, 4)
# Generating advanced features:   0%|          | 0/10000 [00:00<?, ?it/s]
# Generating advanced features:   0%|          | 0/5000 [00:00<?, ?it/s]
# Shapes:
# (8000, 84) (2000, 84) (8000,) (2000,)

# %%
from Models.pipeline import get_pipeline

"""
Available models and recommended scaler usage:

1. Logistic Regression ('logistic')
   - Recommended scaler: RobustScaler (default 'auto')
   - Key parameters: C, penalty ('l1', 'l2'), class_weight

2. Random Forest ('random_forest')
   - Recommended scaler: RobustScaler (default 'auto')
   - Key parameters: n_estimators, max_depth, min_samples_split, min_samples_leaf, max_features

3. XGBoost ('xgboost')
   - Recommended scaler: RobustScaler (default 'auto')
   - Key parameters: n_estimators, max_depth, learning_rate, subsample, colsample_bytree, gamma

4. LightGBM ('lightgbm')
   - Recommended scaler: StandardScaler (default 'auto')
   - Key parameters: n_estimators, num_leaves, learning_rate, max_depth, feature_fraction, bagging_fraction, min_child_samples, lambda_l1, lambda_l2

5. CatBoost ('catboost')
   - Recommended scaler: StandardScaler (default 'auto')
   - Key parameters: depth, learning_rate, iterations, l2_leaf_reg, random_seed, task_type

6. Gradient Boosting ('gradient_boost')
   - Recommended scaler: RobustScaler (default 'auto')
   - Key parameters: n_estimators, max_depth, learning_rate, min_samples_split, min_samples_leaf, subsample
"""

from Models.pipeline import get_pipeline

"""
Pipelines for all supported models.
Each pipeline is created with the recommended scaler unless you override it.
"""

# 1. Logistic Regression
pipeline_logistic = get_pipeline(
    model_name='logistic',
    numerical_features=features,
    scaler='standard' 
)

# 2. Random Forest
pipeline_random_forest = get_pipeline(
    model_name='random_forest',
    numerical_features=features,
    scaler='robust' 
)

# 3. XGBoost
pipeline_xgb = get_pipeline(
    model_name='xgboost',
    numerical_features=features,
    scaler='robust' 
)

# 4. LightGBM
pipeline_lgbm = get_pipeline(
    model_name='lightgbm',
    numerical_features=features,
    scaler='standard'
)

# 5. CatBoost
pipeline_catboost = get_pipeline(
    model_name='catboost',
    numerical_features=features,
    scaler='standard'
)

# 6. Gradient Boosting
pipeline_gradient_boost = get_pipeline(
    model_name='gradient_boost',
    numerical_features=features,
    scaler='robust' 
)

# If you want all of them in one dict:
all_pipelines = {
    "logistic": pipeline_logistic,
    "random_forest": pipeline_random_forest,
    "xgboost": pipeline_xgb,
    "lightgbm": pipeline_lgbm,
    "catboost": pipeline_catboost,
    "gradient_boost": pipeline_gradient_boost
}

# %%
from sklearn.metrics import accuracy_score

# Prepare data
X_train_clean = X_train_split
X_val_clean = X_val_split

results = {}

for name, pipeline in all_pipelines.items():
    print(f"\nTraining {name}...")

    # Fit
    pipeline.fit(X_train_clean, y_train_split)

    # Predict
    preds = pipeline.predict(X_val_clean)

    # Evaluate
    acc = accuracy_score(y_val_split, preds)
    results[name] = acc

    print(f"{name} validation accuracy: {acc:.4f}")

print("\nSummary of results:")
for name, acc in results.items():
    print(f"{name}: {acc:.4f}")
# Out:
# Training logistic...
# logistic validation accuracy: 0.7260
#
# Training random_forest...
# random_forest validation accuracy: 0.7975
#
# Training xgboost...
# xgboost validation accuracy: 0.8210
#
# Training lightgbm...
# [LightGBM] [Info] Number of positive: 4000, number of negative: 4000
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000405 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1590
# [LightGBM] [Info] Number of data points in the train set: 8000, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# lightgbm validation accuracy: 0.8240
#
# Training catboost...
# catboost validation accuracy: 0.8255
#
# Training gradient_boost...
# gradient_boost validation accuracy: 0.8290
#
# Summary of results:
# logistic: 0.7260
# random_forest: 0.7975
# xgboost: 0.8210
# lightgbm: 0.8240
# catboost: 0.8255
# gradient_boost: 0.8290

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

X_train_clean = X_train_split
X_val_clean   = X_val_split

results = {}

for name, pipeline in all_pipelines.items():
    print(f"\n=== {name.upper()} ===")

    # Fit
    pipeline.fit(X_train_clean, y_train_split)

    # Predict labels
    preds = pipeline.predict(X_val_clean)

    # Predict probabilities (if available)
    try:
        probs = pipeline.predict_proba(X_val_clean)[:, 1]
    except:
        probs = None

    # Accuracy
    acc = accuracy_score(y_val_split, preds)
    results[name] = acc
    print(f"Validation Accuracy: {acc:.4f}")

    # Classification report
    print("\nClassification Report:")
    print(classification_report(y_val_split, preds))

    # Confusion matrix
    print("Confusion Matrix:")
    print(confusion_matrix(y_val_split, preds))

    # Store predictions & probs if you want to use later
    results[name] = {
        "accuracy": acc,
        "preds": preds,
        "probs": probs
    }

print("\n=== SUMMARY ===")
for name, info in results.items():
    print(f"{name}: {info['accuracy']:.4f}")
# Out:
# === LOGISTIC ===
# Validation Accuracy: 0.7260
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.72      0.75      0.73      1000
#         True       0.74      0.70      0.72      1000
#
#     accuracy                           0.73      2000
#    macro avg       0.73      0.73      0.73      2000
# weighted avg       0.73      0.73      0.73      2000
#
# Confusion Matrix:
# [[750 250]
#  [298 702]]
#
# === RANDOM_FOREST ===
# Validation Accuracy: 0.7975
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.79      0.81      0.80      1000
#         True       0.81      0.79      0.79      1000
#
#     accuracy                           0.80      2000
#    macro avg       0.80      0.80      0.80      2000
# weighted avg       0.80      0.80      0.80      2000
#
# Confusion Matrix:
# [[810 190]
#  [215 785]]
#
# === XGBOOST ===
# Validation Accuracy: 0.8210
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.81      0.83      0.82      1000
#         True       0.83      0.81      0.82      1000
#
#     accuracy                           0.82      2000
#    macro avg       0.82      0.82      0.82      2000
# weighted avg       0.82      0.82      0.82      2000
#
# Confusion Matrix:
# [[831 169]
#  [189 811]]
#
# === LIGHTGBM ===
# [LightGBM] [Info] Number of positive: 4000, number of negative: 4000
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000605 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1590
# [LightGBM] [Info] Number of data points in the train set: 8000, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Validation Accuracy: 0.8240
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.82      0.83      0.83      1000
#         True       0.83      0.81      0.82      1000
#
#     accuracy                           0.82      2000
#    macro avg       0.82      0.82      0.82      2000
# weighted avg       0.82      0.82      0.82      2000
#
# Confusion Matrix:
# [[833 167]
#  [185 815]]
#
# === CATBOOST ===
# Validation Accuracy: 0.8255
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.82      0.84      0.83      1000
#         True       0.83      0.81      0.82      1000
#
#     accuracy                           0.83      2000
#    macro avg       0.83      0.83      0.83      2000
# weighted avg       0.83      0.83      0.83      2000
#
# Confusion Matrix:
# [[838 162]
#  [187 813]]
#
# === GRADIENT_BOOST ===
# Validation Accuracy: 0.8290
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.83      0.83      0.83      1000
#         True       0.83      0.82      0.83      1000
#
#     accuracy                           0.83      2000
#    macro avg       0.83      0.83      0.83      2000
# weighted avg       0.83      0.83      0.83      2000
#
# Confusion Matrix:
# [[835 165]
#  [177 823]]
#
# === SUMMARY ===
# logistic: 0.7260
# random_forest: 0.7975
# xgboost: 0.8210
# lightgbm: 0.8240
# catboost: 0.8255
# gradient_boost: 0.8290

# %%
from paramethers.cat_grid import param_grid as catboost_param_grid
from paramethers.gb_grid import param_grid_optuna as gradientboost_param_grid
from paramethers.lgb_grid import param_grid as lightgbm_param_grid
from paramethers.log_grid import param_grid as logistic_param_grid
from paramethers.rf_grid import param_grid as randomforest_param_grid
from paramethers.xgb_grid import param_grid_optuna as xgboost_param_grid


from optimisers.gridsearch_optimizer import run_grid_search
from optimisers.optuna_optimizer import optimize_optuna
from optimisers.randomsearch_optimizer import run_random_search

# %%
xgboost_param_grid
catboost_param_grid
gradientboost_param_grid
# Out:
# {'classifier__n_estimators': (200, 500),
#  'classifier__learning_rate': (0.01, 0.2),
#  'classifier__max_depth': (3, 6),
#  'classifier__min_samples_split': (2, 10),
#  'classifier__min_samples_leaf': (1, 4),
#  'classifier__subsample': (0.6, 1.0),
#  'classifier__max_features': ['sqrt', 0.5, 0.7, None],
#  'classifier__random_state': 42}

# %%
# --- XGBOOST ---
best_model, best_params_xgb, best_score_xgb = optimize_optuna(
    lambda: pipeline_xgb,
    X_train_split,
    y_train_split,
    X_val_split,
    y_val_split,
    xgboost_param_grid,
    n_trials=100
)
print("\nBest XGBoost Accuracy:", best_score_xgb)
print("Best XGBoost Params:", best_params_xgb)


# --- LIGHTGBM ---
best_lgbm_model, best_params_lgb, best_score_lgb = optimize_optuna(
    lambda: pipeline_lgbm,
    X_train_split,
    y_train_split,
    X_val_split,
    y_val_split,
    lightgbm_param_grid,
    n_trials=50
)
print("\nBest LightGBM Accuracy:", best_score_lgb)
print("Best LightGBM Params:", best_params_lgb)


# --- GRADIENT BOOSTING ---
best_gb_model, best_params_gb, best_score_gb = optimize_optuna(
    lambda: pipeline_gradient_boost,
    X_train_split,
    y_train_split,
    X_val_split,
    y_val_split,
    gradientboost_param_grid,
    n_trials=50
)
print("\nBest Gradient Boosting Accuracy:", best_score_gb)
print("Best Gradient Boosting Params:", best_params_gb)

'''
# --- CATBOOST ---
best_cat_model, best_params_cat, best_score_cat = optimize_optuna(
    lambda: pipeline_catboost,
    X_train_split,
    y_train_split,
    X_val_split,
    y_val_split,
    catboost_param_grid,
    n_trials=1
)
print("\nBest CatBoost Accuracy:", best_score_cat)
print("Best CatBoost Params:", best_params_cat)
'''
# Out:
# [16:15:50] INFO: Starting Optuna optimization for 100 trials...
# [I 2025-11-15 16:15:50,830] A new study created in memory with name: no-name-1ca8f64d-9e14-4cb4-a47c-21622c1afe93
# [16:15:51] INFO: Trial 1/100 - Accuracy: 0.8275 - Params: {'classifier__max_depth': 4, 'classifier__learning_rate': 0.10293888592588714, 'classifier__subsample': 0.7305420595595353, 'classifier__colsample_bytree': 0.9055449349390458, 'classifier__min_child_weight': 5, 'classifier__gamma': 1.3362506902312425, 'classifier__reg_lambda': 5.3982143514167955, 'classifier__reg_alpha': 7.113893087618578, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:51,133] Trial 0 finished with value: 0.8275 and parameters: {'classifier__max_depth': 4, 'classifier__learning_rate': 0.10293888592588714, 'classifier__subsample': 0.7305420595595353, 'classifier__colsample_bytree': 0.9055449349390458, 'classifier__min_child_weight': 5, 'classifier__gamma': 1.3362506902312425, 'classifier__reg_lambda': 5.3982143514167955, 'classifier__reg_alpha': 7.113893087618578, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 0 with value: 0.8275.
# [16:15:51] INFO: Trial 2/100 - Accuracy: 0.8270 - Params: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.17179184590579238, 'classifier__subsample': 0.9180819623365537, 'classifier__colsample_bytree': 0.9728962828348284, 'classifier__min_child_weight': 5, 'classifier__gamma': 0.1867689112360582, 'classifier__reg_lambda': 6.00595725613128, 'classifier__reg_alpha': 8.61551730215768, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:51,415] Trial 1 finished with value: 0.827 and parameters: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.17179184590579238, 'classifier__subsample': 0.9180819623365537, 'classifier__colsample_bytree': 0.9728962828348284, 'classifier__min_child_weight': 5, 'classifier__gamma': 0.1867689112360582, 'classifier__reg_lambda': 6.00595725613128, 'classifier__reg_alpha': 8.61551730215768, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 0 with value: 0.8275.
# [16:15:51] INFO: Trial 3/100 - Accuracy: 0.8270 - Params: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.21094822896647925, 'classifier__subsample': 0.8600286361589028, 'classifier__colsample_bytree': 0.979383399382408, 'classifier__min_child_weight': 1, 'classifier__gamma': 1.6603515642112054, 'classifier__reg_lambda': 8.882981068609277, 'classifier__reg_alpha': 4.763398081281083, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:51,671] Trial 2 finished with value: 0.827 and parameters: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.21094822896647925, 'classifier__subsample': 0.8600286361589028, 'classifier__colsample_bytree': 0.979383399382408, 'classifier__min_child_weight': 1, 'classifier__gamma': 1.6603515642112054, 'classifier__reg_lambda': 8.882981068609277, 'classifier__reg_alpha': 4.763398081281083, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 0 with value: 0.8275.
# [16:15:51] INFO: Trial 4/100 - Accuracy: 0.8235 - Params: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.2800011552354693, 'classifier__subsample': 0.6106710823980243, 'classifier__colsample_bytree': 0.7575270436727296, 'classifier__min_child_weight': 1, 'classifier__gamma': 4.885565415296089, 'classifier__reg_lambda': 5.2078136608646375, 'classifier__reg_alpha': 8.796323629387906, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:51,881] Trial 3 finished with value: 0.8235 and parameters: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.2800011552354693, 'classifier__subsample': 0.6106710823980243, 'classifier__colsample_bytree': 0.7575270436727296, 'classifier__min_child_weight': 1, 'classifier__gamma': 4.885565415296089, 'classifier__reg_lambda': 5.2078136608646375, 'classifier__reg_alpha': 8.796323629387906, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 0 with value: 0.8275.
# [16:15:52] INFO: Trial 5/100 - Accuracy: 0.8280 - Params: {'classifier__max_depth': 4, 'classifier__learning_rate': 0.16271882035050064, 'classifier__subsample': 0.7147097774832089, 'classifier__colsample_bytree': 0.7721441666570522, 'classifier__min_child_weight': 7, 'classifier__gamma': 4.842998595653196, 'classifier__reg_lambda': 1.7931041081524637, 'classifier__reg_alpha': 7.847113815945076, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:52,076] Trial 4 finished with value: 0.828 and parameters: {'classifier__max_depth': 4, 'classifier__learning_rate': 0.16271882035050064, 'classifier__subsample': 0.7147097774832089, 'classifier__colsample_bytree': 0.7721441666570522, 'classifier__min_child_weight': 7, 'classifier__gamma': 4.842998595653196, 'classifier__reg_lambda': 1.7931041081524637, 'classifier__reg_alpha': 7.847113815945076, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 4 with value: 0.828.
# [16:15:52] INFO: Trial 6/100 - Accuracy: 0.8245 - Params: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.15144550822236294, 'classifier__subsample': 0.932491331033441, 'classifier__colsample_bytree': 0.6656796815883709, 'classifier__min_child_weight': 7, 'classifier__gamma': 0.6666376255680778, 'classifier__reg_lambda': 3.488996377827703, 'classifier__reg_alpha': 4.314594039332041, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:52,294] Trial 5 finished with value: 0.8245 and parameters: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.15144550822236294, 'classifier__subsample': 0.932491331033441, 'classifier__colsample_bytree': 0.6656796815883709, 'classifier__min_child_weight': 7, 'classifier__gamma': 0.6666376255680778, 'classifier__reg_lambda': 3.488996377827703, 'classifier__reg_alpha': 4.314594039332041, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 4 with value: 0.828.
# [16:15:52] INFO: Trial 7/100 - Accuracy: 0.8270 - Params: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.05239947105966488, 'classifier__subsample': 0.701015532932495, 'classifier__colsample_bytree': 0.7466050522871017, 'classifier__min_child_weight': 7, 'classifier__gamma': 3.0285785997620867, 'classifier__reg_lambda': 0.8389805745717511, 'classifier__reg_alpha': 3.961111532773666, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:52,543] Trial 6 finished with value: 0.827 and parameters: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.05239947105966488, 'classifier__subsample': 0.701015532932495, 'classifier__colsample_bytree': 0.7466050522871017, 'classifier__min_child_weight': 7, 'classifier__gamma': 3.0285785997620867, 'classifier__reg_lambda': 0.8389805745717511, 'classifier__reg_alpha': 3.961111532773666, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 4 with value: 0.828.
# [16:15:52] INFO: Trial 8/100 - Accuracy: 0.8310 - Params: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.07135117139679033, 'classifier__subsample': 0.6402642208394775, 'classifier__colsample_bytree': 0.6905149785891288, 'classifier__min_child_weight': 8, 'classifier__gamma': 3.9307092481916603, 'classifier__reg_lambda': 0.4824686492097473, 'classifier__reg_alpha': 0.5956502874985979, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:52,749] Trial 7 finished with value: 0.831 and parameters: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.07135117139679033, 'classifier__subsample': 0.6402642208394775, 'classifier__colsample_bytree': 0.6905149785891288, 'classifier__min_child_weight': 8, 'classifier__gamma': 3.9307092481916603, 'classifier__reg_lambda': 0.4824686492097473, 'classifier__reg_alpha': 0.5956502874985979, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 7 with value: 0.831.
# [16:15:52] INFO: Trial 9/100 - Accuracy: 0.8300 - Params: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.1509153454396829, 'classifier__subsample': 0.7257026381579113, 'classifier__colsample_bytree': 0.6629043020991889, 'classifier__min_child_weight': 5, 'classifier__gamma': 1.761237993229607, 'classifier__reg_lambda': 1.8019189677048055, 'classifier__reg_alpha': 8.792535957564446, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:52,970] Trial 8 finished with value: 0.83 and parameters: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.1509153454396829, 'classifier__subsample': 0.7257026381579113, 'classifier__colsample_bytree': 0.6629043020991889, 'classifier__min_child_weight': 5, 'classifier__gamma': 1.761237993229607, 'classifier__reg_lambda': 1.8019189677048055, 'classifier__reg_alpha': 8.792535957564446, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 7 with value: 0.831.
# [16:15:53] INFO: Trial 10/100 - Accuracy: 0.8315 - Params: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.2822336185087634, 'classifier__subsample': 0.663861424305403, 'classifier__colsample_bytree': 0.707414773758577, 'classifier__min_child_weight': 10, 'classifier__gamma': 1.910910281732983, 'classifier__reg_lambda': 1.5004594449972424, 'classifier__reg_alpha': 5.63219669533842, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:53,169] Trial 9 finished with value: 0.8315 and parameters: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.2822336185087634, 'classifier__subsample': 0.663861424305403, 'classifier__colsample_bytree': 0.707414773758577, 'classifier__min_child_weight': 10, 'classifier__gamma': 1.910910281732983, 'classifier__reg_lambda': 1.5004594449972424, 'classifier__reg_alpha': 5.63219669533842, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:53] INFO: Trial 11/100 - Accuracy: 0.8235 - Params: {'classifier__max_depth': 8, 'classifier__learning_rate': 0.2895051028665258, 'classifier__subsample': 0.8123027607463531, 'classifier__colsample_bytree': 0.6082097809958424, 'classifier__min_child_weight': 10, 'classifier__gamma': 2.845770411018342, 'classifier__reg_lambda': 8.0496345623381, 'classifier__reg_alpha': 1.775535630284165, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:53,422] Trial 10 finished with value: 0.8235 and parameters: {'classifier__max_depth': 8, 'classifier__learning_rate': 0.2895051028665258, 'classifier__subsample': 0.8123027607463531, 'classifier__colsample_bytree': 0.6082097809958424, 'classifier__min_child_weight': 10, 'classifier__gamma': 2.845770411018342, 'classifier__reg_lambda': 8.0496345623381, 'classifier__reg_alpha': 1.775535630284165, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:53] INFO: Trial 12/100 - Accuracy: 0.8295 - Params: {'classifier__max_depth': 3, 'classifier__learning_rate': 0.05305911483149821, 'classifier__subsample': 0.6016554519528164, 'classifier__colsample_bytree': 0.6977467603014621, 'classifier__min_child_weight': 10, 'classifier__gamma': 3.723206351622364, 'classifier__reg_lambda': 0.10727073834948841, 'classifier__reg_alpha': 0.12255598276298907, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:53,659] Trial 11 finished with value: 0.8295 and parameters: {'classifier__max_depth': 3, 'classifier__learning_rate': 0.05305911483149821, 'classifier__subsample': 0.6016554519528164, 'classifier__colsample_bytree': 0.6977467603014621, 'classifier__min_child_weight': 10, 'classifier__gamma': 3.723206351622364, 'classifier__reg_lambda': 0.10727073834948841, 'classifier__reg_alpha': 0.12255598276298907, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:54] INFO: Trial 13/100 - Accuracy: 0.8265 - Params: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.010493337986453785, 'classifier__subsample': 0.653637586727732, 'classifier__colsample_bytree': 0.854051217710285, 'classifier__min_child_weight': 9, 'classifier__gamma': 3.7272556044104146, 'classifier__reg_lambda': 3.2077286667171543, 'classifier__reg_alpha': 6.301508457298744, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:54,017] Trial 12 finished with value: 0.8265 and parameters: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.010493337986453785, 'classifier__subsample': 0.653637586727732, 'classifier__colsample_bytree': 0.854051217710285, 'classifier__min_child_weight': 9, 'classifier__gamma': 3.7272556044104146, 'classifier__reg_lambda': 3.2077286667171543, 'classifier__reg_alpha': 6.301508457298744, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:54] INFO: Trial 14/100 - Accuracy: 0.8275 - Params: {'classifier__max_depth': 8, 'classifier__learning_rate': 0.22001299334570135, 'classifier__subsample': 0.6634904648951869, 'classifier__colsample_bytree': 0.831084781576716, 'classifier__min_child_weight': 8, 'classifier__gamma': 2.370251546513023, 'classifier__reg_lambda': 3.090199547293688, 'classifier__reg_alpha': 2.584353416192646, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:54,335] Trial 13 finished with value: 0.8275 and parameters: {'classifier__max_depth': 8, 'classifier__learning_rate': 0.22001299334570135, 'classifier__subsample': 0.6634904648951869, 'classifier__colsample_bytree': 0.831084781576716, 'classifier__min_child_weight': 8, 'classifier__gamma': 2.370251546513023, 'classifier__reg_lambda': 3.090199547293688, 'classifier__reg_alpha': 2.584353416192646, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:54] INFO: Trial 15/100 - Accuracy: 0.8280 - Params: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.09644429653159403, 'classifier__subsample': 0.7977816578464362, 'classifier__colsample_bytree': 0.6060594180409379, 'classifier__min_child_weight': 9, 'classifier__gamma': 3.8935706467835725, 'classifier__reg_lambda': 1.4637729621239508, 'classifier__reg_alpha': 6.0821715669136065, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:54,632] Trial 14 finished with value: 0.828 and parameters: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.09644429653159403, 'classifier__subsample': 0.7977816578464362, 'classifier__colsample_bytree': 0.6060594180409379, 'classifier__min_child_weight': 9, 'classifier__gamma': 3.8935706467835725, 'classifier__reg_lambda': 1.4637729621239508, 'classifier__reg_alpha': 6.0821715669136065, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:54] INFO: Trial 16/100 - Accuracy: 0.8270 - Params: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.2452233563771864, 'classifier__subsample': 0.9986976499531165, 'classifier__colsample_bytree': 0.7144834953482069, 'classifier__min_child_weight': 3, 'classifier__gamma': 2.2934456871961504, 'classifier__reg_lambda': 7.039068810715007, 'classifier__reg_alpha': 0.14820314539326507, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:54,861] Trial 15 finished with value: 0.827 and parameters: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.2452233563771864, 'classifier__subsample': 0.9986976499531165, 'classifier__colsample_bytree': 0.7144834953482069, 'classifier__min_child_weight': 3, 'classifier__gamma': 2.2934456871961504, 'classifier__reg_lambda': 7.039068810715007, 'classifier__reg_alpha': 0.14820314539326507, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:55] INFO: Trial 17/100 - Accuracy: 0.8285 - Params: {'classifier__max_depth': 4, 'classifier__learning_rate': 0.09790732839215091, 'classifier__subsample': 0.6419983505131587, 'classifier__colsample_bytree': 0.665296592031276, 'classifier__min_child_weight': 8, 'classifier__gamma': 4.220513641647525, 'classifier__reg_lambda': 0.11613691950406224, 'classifier__reg_alpha': 3.092366670498277, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:55,081] Trial 16 finished with value: 0.8285 and parameters: {'classifier__max_depth': 4, 'classifier__learning_rate': 0.09790732839215091, 'classifier__subsample': 0.6419983505131587, 'classifier__colsample_bytree': 0.665296592031276, 'classifier__min_child_weight': 8, 'classifier__gamma': 4.220513641647525, 'classifier__reg_lambda': 0.11613691950406224, 'classifier__reg_alpha': 3.092366670498277, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:55] INFO: Trial 18/100 - Accuracy: 0.8295 - Params: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.01057528437296551, 'classifier__subsample': 0.7696118600381042, 'classifier__colsample_bytree': 0.8064793835098323, 'classifier__min_child_weight': 10, 'classifier__gamma': 3.1858000068333245, 'classifier__reg_lambda': 4.159732366895601, 'classifier__reg_alpha': 1.5022851479717434, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:55,451] Trial 17 finished with value: 0.8295 and parameters: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.01057528437296551, 'classifier__subsample': 0.7696118600381042, 'classifier__colsample_bytree': 0.8064793835098323, 'classifier__min_child_weight': 10, 'classifier__gamma': 3.1858000068333245, 'classifier__reg_lambda': 4.159732366895601, 'classifier__reg_alpha': 1.5022851479717434, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:55] INFO: Trial 19/100 - Accuracy: 0.8260 - Params: {'classifier__max_depth': 3, 'classifier__learning_rate': 0.1245292057271287, 'classifier__subsample': 0.6564361130427047, 'classifier__colsample_bytree': 0.7086739610118423, 'classifier__min_child_weight': 8, 'classifier__gamma': 0.9014961879394887, 'classifier__reg_lambda': 1.8523791378753796, 'classifier__reg_alpha': 5.737006516822998, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:55,691] Trial 18 finished with value: 0.826 and parameters: {'classifier__max_depth': 3, 'classifier__learning_rate': 0.1245292057271287, 'classifier__subsample': 0.6564361130427047, 'classifier__colsample_bytree': 0.7086739610118423, 'classifier__min_child_weight': 8, 'classifier__gamma': 0.9014961879394887, 'classifier__reg_lambda': 1.8523791378753796, 'classifier__reg_alpha': 5.737006516822998, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:55] INFO: Trial 20/100 - Accuracy: 0.8290 - Params: {'classifier__max_depth': 8, 'classifier__learning_rate': 0.05938577854775709, 'classifier__subsample': 0.6901451945407356, 'classifier__colsample_bytree': 0.8820012587366157, 'classifier__min_child_weight': 6, 'classifier__gamma': 2.1004664109273, 'classifier__reg_lambda': 2.8992699090680425, 'classifier__reg_alpha': 9.950828960829785, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:55,974] Trial 19 finished with value: 0.829 and parameters: {'classifier__max_depth': 8, 'classifier__learning_rate': 0.05938577854775709, 'classifier__subsample': 0.6901451945407356, 'classifier__colsample_bytree': 0.8820012587366157, 'classifier__min_child_weight': 6, 'classifier__gamma': 2.1004664109273, 'classifier__reg_lambda': 2.8992699090680425, 'classifier__reg_alpha': 9.950828960829785, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:56] INFO: Trial 21/100 - Accuracy: 0.8305 - Params: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.1983180017285116, 'classifier__subsample': 0.7610213012268282, 'classifier__colsample_bytree': 0.6487733714003502, 'classifier__min_child_weight': 9, 'classifier__gamma': 4.322191514552047, 'classifier__reg_lambda': 9.9106324130169, 'classifier__reg_alpha': 3.4742731020624595, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:56,200] Trial 20 finished with value: 0.8305 and parameters: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.1983180017285116, 'classifier__subsample': 0.7610213012268282, 'classifier__colsample_bytree': 0.6487733714003502, 'classifier__min_child_weight': 9, 'classifier__gamma': 4.322191514552047, 'classifier__reg_lambda': 9.9106324130169, 'classifier__reg_alpha': 3.4742731020624595, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:56] INFO: Trial 22/100 - Accuracy: 0.8305 - Params: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.24215531728587167, 'classifier__subsample': 0.7656565445107446, 'classifier__colsample_bytree': 0.6480664224164099, 'classifier__min_child_weight': 9, 'classifier__gamma': 4.4656369094771655, 'classifier__reg_lambda': 9.892330277394723, 'classifier__reg_alpha': 3.4768204080703904, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:56,467] Trial 21 finished with value: 0.8305 and parameters: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.24215531728587167, 'classifier__subsample': 0.7656565445107446, 'classifier__colsample_bytree': 0.6480664224164099, 'classifier__min_child_weight': 9, 'classifier__gamma': 4.4656369094771655, 'classifier__reg_lambda': 9.892330277394723, 'classifier__reg_alpha': 3.4768204080703904, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:56] INFO: Trial 23/100 - Accuracy: 0.8295 - Params: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.18383335091089095, 'classifier__subsample': 0.8440204549782854, 'classifier__colsample_bytree': 0.7367346668502536, 'classifier__min_child_weight': 9, 'classifier__gamma': 3.3557398868927493, 'classifier__reg_lambda': 6.748016112208322, 'classifier__reg_alpha': 5.366126600641536, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:56,737] Trial 22 finished with value: 0.8295 and parameters: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.18383335091089095, 'classifier__subsample': 0.8440204549782854, 'classifier__colsample_bytree': 0.7367346668502536, 'classifier__min_child_weight': 9, 'classifier__gamma': 3.3557398868927493, 'classifier__reg_lambda': 6.748016112208322, 'classifier__reg_alpha': 5.366126600641536, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:57] INFO: Trial 24/100 - Accuracy: 0.8300 - Params: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.25033530250982566, 'classifier__subsample': 0.7632077289868778, 'classifier__colsample_bytree': 0.6379739435788062, 'classifier__min_child_weight': 10, 'classifier__gamma': 4.2756152494336765, 'classifier__reg_lambda': 4.432328892099998, 'classifier__reg_alpha': 1.1694155977597749, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:57,007] Trial 23 finished with value: 0.83 and parameters: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.25033530250982566, 'classifier__subsample': 0.7632077289868778, 'classifier__colsample_bytree': 0.6379739435788062, 'classifier__min_child_weight': 10, 'classifier__gamma': 4.2756152494336765, 'classifier__reg_lambda': 4.432328892099998, 'classifier__reg_alpha': 1.1694155977597749, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:57] INFO: Trial 25/100 - Accuracy: 0.8295 - Params: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.19875599956830622, 'classifier__subsample': 0.6260809722184012, 'classifier__colsample_bytree': 0.6897873135478674, 'classifier__min_child_weight': 8, 'classifier__gamma': 2.566303523392474, 'classifier__reg_lambda': 9.879803397453104, 'classifier__reg_alpha': 2.258808586001739, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:57,330] Trial 24 finished with value: 0.8295 and parameters: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.19875599956830622, 'classifier__subsample': 0.6260809722184012, 'classifier__colsample_bytree': 0.6897873135478674, 'classifier__min_child_weight': 8, 'classifier__gamma': 2.566303523392474, 'classifier__reg_lambda': 9.879803397453104, 'classifier__reg_alpha': 2.258808586001739, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:57] INFO: Trial 26/100 - Accuracy: 0.8305 - Params: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.2749946685470893, 'classifier__subsample': 0.6751837469831805, 'classifier__colsample_bytree': 0.7887604873404446, 'classifier__min_child_weight': 6, 'classifier__gamma': 3.4445666603477414, 'classifier__reg_lambda': 0.6665069503067712, 'classifier__reg_alpha': 6.668817001885721, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:57,589] Trial 25 finished with value: 0.8305 and parameters: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.2749946685470893, 'classifier__subsample': 0.6751837469831805, 'classifier__colsample_bytree': 0.7887604873404446, 'classifier__min_child_weight': 6, 'classifier__gamma': 3.4445666603477414, 'classifier__reg_lambda': 0.6665069503067712, 'classifier__reg_alpha': 6.668817001885721, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:57] INFO: Trial 27/100 - Accuracy: 0.8295 - Params: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.1278615798670282, 'classifier__subsample': 0.7407112828312046, 'classifier__colsample_bytree': 0.6214902130109117, 'classifier__min_child_weight': 9, 'classifier__gamma': 4.523651974213819, 'classifier__reg_lambda': 2.555855618152039, 'classifier__reg_alpha': 0.8506823754865236, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:57,862] Trial 26 finished with value: 0.8295 and parameters: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.1278615798670282, 'classifier__subsample': 0.7407112828312046, 'classifier__colsample_bytree': 0.6214902130109117, 'classifier__min_child_weight': 9, 'classifier__gamma': 4.523651974213819, 'classifier__reg_lambda': 2.555855618152039, 'classifier__reg_alpha': 0.8506823754865236, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:58] INFO: Trial 28/100 - Accuracy: 0.8285 - Params: {'classifier__max_depth': 4, 'classifier__learning_rate': 0.26306555866707493, 'classifier__subsample': 0.687475832111266, 'classifier__colsample_bytree': 0.7275827321268503, 'classifier__min_child_weight': 4, 'classifier__gamma': 3.971665411384555, 'classifier__reg_lambda': 7.790320680500988, 'classifier__reg_alpha': 4.5140888038523155, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:58,125] Trial 27 finished with value: 0.8285 and parameters: {'classifier__max_depth': 4, 'classifier__learning_rate': 0.26306555866707493, 'classifier__subsample': 0.687475832111266, 'classifier__colsample_bytree': 0.7275827321268503, 'classifier__min_child_weight': 4, 'classifier__gamma': 3.971665411384555, 'classifier__reg_lambda': 7.790320680500988, 'classifier__reg_alpha': 4.5140888038523155, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:58] INFO: Trial 29/100 - Accuracy: 0.8315 - Params: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.2265483202203798, 'classifier__subsample': 0.7938942166781322, 'classifier__colsample_bytree': 0.6829367042793693, 'classifier__min_child_weight': 10, 'classifier__gamma': 2.800585549078556, 'classifier__reg_lambda': 1.1003160276457327, 'classifier__reg_alpha': 3.3616186759230207, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:58,401] Trial 28 finished with value: 0.8315 and parameters: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.2265483202203798, 'classifier__subsample': 0.7938942166781322, 'classifier__colsample_bytree': 0.6829367042793693, 'classifier__min_child_weight': 10, 'classifier__gamma': 2.800585549078556, 'classifier__reg_lambda': 1.1003160276457327, 'classifier__reg_alpha': 3.3616186759230207, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:58] INFO: Trial 30/100 - Accuracy: 0.8245 - Params: {'classifier__max_depth': 8, 'classifier__learning_rate': 0.29930412496186054, 'classifier__subsample': 0.8808345783191324, 'classifier__colsample_bytree': 0.6852240852559451, 'classifier__min_child_weight': 10, 'classifier__gamma': 1.1065366057493051, 'classifier__reg_lambda': 1.0151996715400253, 'classifier__reg_alpha': 7.268803289599184, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:58,666] Trial 29 finished with value: 0.8245 and parameters: {'classifier__max_depth': 8, 'classifier__learning_rate': 0.29930412496186054, 'classifier__subsample': 0.8808345783191324, 'classifier__colsample_bytree': 0.6852240852559451, 'classifier__min_child_weight': 10, 'classifier__gamma': 1.1065366057493051, 'classifier__reg_lambda': 1.0151996715400253, 'classifier__reg_alpha': 7.268803289599184, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:58] INFO: Trial 31/100 - Accuracy: 0.8305 - Params: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.23758426900083435, 'classifier__subsample': 0.8138942619555875, 'classifier__colsample_bytree': 0.8028768558111302, 'classifier__min_child_weight': 10, 'classifier__gamma': 2.7247813595518933, 'classifier__reg_lambda': 2.2695436439274927, 'classifier__reg_alpha': 5.158284117039702, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:58,928] Trial 30 finished with value: 0.8305 and parameters: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.23758426900083435, 'classifier__subsample': 0.8138942619555875, 'classifier__colsample_bytree': 0.8028768558111302, 'classifier__min_child_weight': 10, 'classifier__gamma': 2.7247813595518933, 'classifier__reg_lambda': 2.2695436439274927, 'classifier__reg_alpha': 5.158284117039702, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:59] INFO: Trial 32/100 - Accuracy: 0.8265 - Params: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.22363479627798327, 'classifier__subsample': 0.7385839541259511, 'classifier__colsample_bytree': 0.6413397893343786, 'classifier__min_child_weight': 9, 'classifier__gamma': 1.8270165127649465, 'classifier__reg_lambda': 1.1977525485830254, 'classifier__reg_alpha': 3.5227149255748866, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:59,189] Trial 31 finished with value: 0.8265 and parameters: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.22363479627798327, 'classifier__subsample': 0.7385839541259511, 'classifier__colsample_bytree': 0.6413397893343786, 'classifier__min_child_weight': 9, 'classifier__gamma': 1.8270165127649465, 'classifier__reg_lambda': 1.1977525485830254, 'classifier__reg_alpha': 3.5227149255748866, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:59] INFO: Trial 33/100 - Accuracy: 0.8230 - Params: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.17862762129172524, 'classifier__subsample': 0.7939895593893574, 'classifier__colsample_bytree': 0.6862190381373876, 'classifier__min_child_weight': 8, 'classifier__gamma': 1.4154640768863829, 'classifier__reg_lambda': 0.4154903821068162, 'classifier__reg_alpha': 2.434178343138251, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:59,432] Trial 32 finished with value: 0.823 and parameters: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.17862762129172524, 'classifier__subsample': 0.7939895593893574, 'classifier__colsample_bytree': 0.6862190381373876, 'classifier__min_child_weight': 8, 'classifier__gamma': 1.4154640768863829, 'classifier__reg_lambda': 0.4154903821068162, 'classifier__reg_alpha': 2.434178343138251, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:15:59] INFO: Trial 34/100 - Accuracy: 0.8225 - Params: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.19509394596517557, 'classifier__subsample': 0.8440069741841946, 'classifier__colsample_bytree': 0.7242863012938133, 'classifier__min_child_weight': 9, 'classifier__gamma': 0.08601435083670328, 'classifier__reg_lambda': 6.1994828503265005, 'classifier__reg_alpha': 3.9028306412791998, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:15:59,786] Trial 33 finished with value: 0.8225 and parameters: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.19509394596517557, 'classifier__subsample': 0.8440069741841946, 'classifier__colsample_bytree': 0.7242863012938133, 'classifier__min_child_weight': 9, 'classifier__gamma': 0.08601435083670328, 'classifier__reg_lambda': 6.1994828503265005, 'classifier__reg_alpha': 3.9028306412791998, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:16:00] INFO: Trial 35/100 - Accuracy: 0.8235 - Params: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.2629106696527835, 'classifier__subsample': 0.6274521450042857, 'classifier__colsample_bytree': 0.9508521022203716, 'classifier__min_child_weight': 10, 'classifier__gamma': 2.0233546423512574, 'classifier__reg_lambda': 4.329214378642648, 'classifier__reg_alpha': 3.125984841286388, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:16:00,038] Trial 34 finished with value: 0.8235 and parameters: {'classifier__max_depth': 5, 'classifier__learning_rate': 0.2629106696527835, 'classifier__subsample': 0.6274521450042857, 'classifier__colsample_bytree': 0.9508521022203716, 'classifier__min_child_weight': 10, 'classifier__gamma': 2.0233546423512574, 'classifier__reg_lambda': 4.329214378642648, 'classifier__reg_alpha': 3.125984841286388, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:16:00] INFO: Trial 36/100 - Accuracy: 0.8295 - Params: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.20867096101830784, 'classifier__subsample': 0.7121266287131155, 'classifier__colsample_bytree': 0.7588427328500236, 'classifier__min_child_weight': 7, 'classifier__gamma': 4.915147676773713, 'classifier__reg_lambda': 5.593506541591355, 'classifier__reg_alpha': 4.817459550398606, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:16:00,298] Trial 35 finished with value: 0.8295 and parameters: {'classifier__max_depth': 6, 'classifier__learning_rate': 0.20867096101830784, 'classifier__subsample': 0.7121266287131155, 'classifier__colsample_bytree': 0.7588427328500236, 'classifier__min_child_weight': 7, 'classifier__gamma': 4.915147676773713, 'classifier__reg_lambda': 5.593506541591355, 'classifier__reg_alpha': 4.817459550398606, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:16:00] INFO: Trial 37/100 - Accuracy: 0.8270 - Params: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.23398228268503118, 'classifier__subsample': 0.8960514171098876, 'classifier__colsample_bytree': 0.6311846991400721, 'classifier__min_child_weight': 3, 'classifier__gamma': 1.458621928099448, 'classifier__reg_lambda': 9.179549828046873, 'classifier__reg_alpha': 0.798763320746128, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:16:00,566] Trial 36 finished with value: 0.827 and parameters: {'classifier__max_depth': 7, 'classifier__learning_rate': 0.23398228268503118, 'classifier__subsample': 0.8960514171098876, 'classifier__colsample_bytree': 0.6311846991400721, 'classifier__min_child_weight': 3, 'classifier__gamma': 1.458621928099448, 'classifier__reg_lambda': 9.179549828046873, 'classifier__reg_alpha': 0.798763320746128, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:16:00] INFO: Trial 38/100 - Accuracy: 0.8290 - Params: {'classifier__max_depth': 4, 'classifier__learning_rate': 0.263759881706505, 'classifier__subsample': 0.77946725507532, 'classifier__colsample_bytree': 0.6704101876029359, 'classifier__min_child_weight': 8, 'classifier__gamma': 3.5795850222226897, 'classifier__reg_lambda': 2.289470389119697, 'classifier__reg_alpha': 7.173605343510363, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:16:00,849] Trial 37 finished with value: 0.829 and parameters: {'classifier__max_depth': 4, 'classifier__learning_rate': 0.263759881706505, 'classifier__subsample': 0.77946725507532, 'classifier__colsample_bytree': 0.6704101876029359, 'classifier__min_child_weight': 8, 'classifier__gamma': 3.5795850222226897, 'classifier__reg_lambda': 2.289470389119697, 'classifier__reg_alpha': 7.173605343510363, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# [16:16:01] INFO: Trial 39/100 - Accuracy: 0.8255 - Params: {'classifier__max_depth': 8, 'classifier__learning_rate': 0.1320930393874346, 'classifier__subsample': 0.8312085939774964, 'classifier__colsample_bytree': 0.7748931700689609, 'classifier__min_child_weight': 6, 'classifier__gamma': 4.607636589036815, 'classifier__reg_lambda': 1.3979063428619376, 'classifier__reg_alpha': 7.855340759782856, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}
# [I 2025-11-15 16:16:01,085] Trial 38 finished with value: 0.8255 and parameters: {'classifier__max_depth': 8, 'classifier__learning_rate': 0.1320930393874346, 'classifier__subsample': 0.8312085939774964, 'classifier__colsample_bytree': 0.7748931700689609, 'classifier__min_child_weight': 6, 'classifier__gamma': 4.607636589036815, 'classifier__reg_lambda': 1.3979063428619376, 'classifier__reg_alpha': 7.855340759782856, 'classifier__n_estimators': 300, 'classifier__random_state': 42, 'classifier__eval_metric': 'logloss', 'classifier__use_label_encoder': False, 'classifier__tree_method': 'hist'}. Best is trial 9 with value: 0.8315.
# ...
# [16:23:17] INFO: Trial 31/50 - Accuracy: 0.8280 - Params: {'classifier__n_estimators': 200, 'classifier__learning_rate': 0.029539290139774, 'classifier__max_depth': 3, 'classifier__min_samples_split': 4, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7344343933881311, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:23:17,395] Trial 30 finished with value: 0.828 and parameters: {'classifier__n_estimators': 200, 'classifier__learning_rate': 0.029539290139774, 'classifier__max_depth': 3, 'classifier__min_samples_split': 4, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7344343933881311, 'classifier__max_features': 0.5}. Best is trial 23 with value: 0.8305.
# [16:23:21] INFO: Trial 32/50 - Accuracy: 0.8295 - Params: {'classifier__n_estimators': 399, 'classifier__learning_rate': 0.02805393417925798, 'classifier__max_depth': 3, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.9984502538913279, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:23:21,970] Trial 31 finished with value: 0.8295 and parameters: {'classifier__n_estimators': 399, 'classifier__learning_rate': 0.02805393417925798, 'classifier__max_depth': 3, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.9984502538913279, 'classifier__max_features': 0.5}. Best is trial 23 with value: 0.8305.
# [16:23:25] INFO: Trial 33/50 - Accuracy: 0.8290 - Params: {'classifier__n_estimators': 353, 'classifier__learning_rate': 0.025916669324813887, 'classifier__max_depth': 3, 'classifier__min_samples_split': 6, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.9714784217450683, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:23:25,890] Trial 32 finished with value: 0.829 and parameters: {'classifier__n_estimators': 353, 'classifier__learning_rate': 0.025916669324813887, 'classifier__max_depth': 3, 'classifier__min_samples_split': 6, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.9714784217450683, 'classifier__max_features': 0.5}. Best is trial 23 with value: 0.8305.
# [16:23:30] INFO: Trial 34/50 - Accuracy: 0.8255 - Params: {'classifier__n_estimators': 392, 'classifier__learning_rate': 0.047705704452332895, 'classifier__max_depth': 3, 'classifier__min_samples_split': 4, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.9702687896714678, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:23:30,269] Trial 33 finished with value: 0.8255 and parameters: {'classifier__n_estimators': 392, 'classifier__learning_rate': 0.047705704452332895, 'classifier__max_depth': 3, 'classifier__min_samples_split': 4, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.9702687896714678, 'classifier__max_features': 0.5}. Best is trial 23 with value: 0.8305.
# [16:23:33] INFO: Trial 35/50 - Accuracy: 0.8320 - Params: {'classifier__n_estimators': 328, 'classifier__learning_rate': 0.023093275921250805, 'classifier__max_depth': 3, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.6681042240479405, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:23:33,200] Trial 34 finished with value: 0.832 and parameters: {'classifier__n_estimators': 328, 'classifier__learning_rate': 0.023093275921250805, 'classifier__max_depth': 3, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.6681042240479405, 'classifier__max_features': 0.5}. Best is trial 34 with value: 0.832.
# [16:23:36] INFO: Trial 36/50 - Accuracy: 0.8275 - Params: {'classifier__n_estimators': 306, 'classifier__learning_rate': 0.047195484429986764, 'classifier__max_depth': 4, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.690985326475423, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:23:36,883] Trial 35 finished with value: 0.8275 and parameters: {'classifier__n_estimators': 306, 'classifier__learning_rate': 0.047195484429986764, 'classifier__max_depth': 4, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.690985326475423, 'classifier__max_features': 0.5}. Best is trial 34 with value: 0.832.
# [16:23:40] INFO: Trial 37/50 - Accuracy: 0.8240 - Params: {'classifier__n_estimators': 362, 'classifier__learning_rate': 0.08303967855835409, 'classifier__max_depth': 4, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 1, 'classifier__subsample': 0.7923310885324972, 'classifier__max_features': 'sqrt', 'classifier__random_state': 42}
# [I 2025-11-15 16:23:40,103] Trial 36 finished with value: 0.824 and parameters: {'classifier__n_estimators': 362, 'classifier__learning_rate': 0.08303967855835409, 'classifier__max_depth': 4, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 1, 'classifier__subsample': 0.7923310885324972, 'classifier__max_features': 'sqrt'}. Best is trial 34 with value: 0.832.
# [16:23:43] INFO: Trial 38/50 - Accuracy: 0.8210 - Params: {'classifier__n_estimators': 328, 'classifier__learning_rate': 0.18005822939060595, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.6948820143666017, 'classifier__max_features': 0.7, 'classifier__random_state': 42}
# [I 2025-11-15 16:23:43,712] Trial 37 finished with value: 0.821 and parameters: {'classifier__n_estimators': 328, 'classifier__learning_rate': 0.18005822939060595, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.6948820143666017, 'classifier__max_features': 0.7}. Best is trial 34 with value: 0.832.
# [16:23:46] INFO: Trial 39/50 - Accuracy: 0.8260 - Params: {'classifier__n_estimators': 289, 'classifier__learning_rate': 0.06405989135763178, 'classifier__max_depth': 3, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.6529792570223273, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:23:46,288] Trial 38 finished with value: 0.826 and parameters: {'classifier__n_estimators': 289, 'classifier__learning_rate': 0.06405989135763178, 'classifier__max_depth': 3, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.6529792570223273, 'classifier__max_features': 0.5}. Best is trial 34 with value: 0.832.
# [16:23:52] INFO: Trial 40/50 - Accuracy: 0.8275 - Params: {'classifier__n_estimators': 439, 'classifier__learning_rate': 0.02400395240220877, 'classifier__max_depth': 4, 'classifier__min_samples_split': 4, 'classifier__min_samples_leaf': 1, 'classifier__subsample': 0.9311491258000979, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:23:52,347] Trial 39 finished with value: 0.8275 and parameters: {'classifier__n_estimators': 439, 'classifier__learning_rate': 0.02400395240220877, 'classifier__max_depth': 4, 'classifier__min_samples_split': 4, 'classifier__min_samples_leaf': 1, 'classifier__subsample': 0.9311491258000979, 'classifier__max_features': 0.5}. Best is trial 34 with value: 0.832.
# [16:23:59] INFO: Trial 41/50 - Accuracy: 0.8165 - Params: {'classifier__n_estimators': 393, 'classifier__learning_rate': 0.040712552085814147, 'classifier__max_depth': 6, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.8081498970515802, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:23:59,743] Trial 40 finished with value: 0.8165 and parameters: {'classifier__n_estimators': 393, 'classifier__learning_rate': 0.040712552085814147, 'classifier__max_depth': 6, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.8081498970515802, 'classifier__max_features': 0.5}. Best is trial 34 with value: 0.832.
# [16:24:03] INFO: Trial 42/50 - Accuracy: 0.8285 - Params: {'classifier__n_estimators': 342, 'classifier__learning_rate': 0.022285437864521612, 'classifier__max_depth': 3, 'classifier__min_samples_split': 7, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.9739875398190759, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:24:03,824] Trial 41 finished with value: 0.8285 and parameters: {'classifier__n_estimators': 342, 'classifier__learning_rate': 0.022285437864521612, 'classifier__max_depth': 3, 'classifier__min_samples_split': 7, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.9739875398190759, 'classifier__max_features': 0.5}. Best is trial 34 with value: 0.832.
# [16:24:07] INFO: Trial 43/50 - Accuracy: 0.8310 - Params: {'classifier__n_estimators': 314, 'classifier__learning_rate': 0.019315738629467887, 'classifier__max_depth': 3, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7608354764932908, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:24:07,059] Trial 42 finished with value: 0.831 and parameters: {'classifier__n_estimators': 314, 'classifier__learning_rate': 0.019315738629467887, 'classifier__max_depth': 3, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7608354764932908, 'classifier__max_features': 0.5}. Best is trial 34 with value: 0.832.
# [16:24:11] INFO: Trial 44/50 - Accuracy: 0.8275 - Params: {'classifier__n_estimators': 298, 'classifier__learning_rate': 0.03749199602618086, 'classifier__max_depth': 3, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7306982194146814, 'classifier__max_features': None, 'classifier__random_state': 42}
# [I 2025-11-15 16:24:11,983] Trial 43 finished with value: 0.8275 and parameters: {'classifier__n_estimators': 298, 'classifier__learning_rate': 0.03749199602618086, 'classifier__max_depth': 3, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7306982194146814, 'classifier__max_features': None}. Best is trial 34 with value: 0.832.
# [16:24:14] INFO: Trial 45/50 - Accuracy: 0.8280 - Params: {'classifier__n_estimators': 271, 'classifier__learning_rate': 0.019796632806602134, 'classifier__max_depth': 3, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.6024900560253779, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:24:14,430] Trial 44 finished with value: 0.828 and parameters: {'classifier__n_estimators': 271, 'classifier__learning_rate': 0.019796632806602134, 'classifier__max_depth': 3, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.6024900560253779, 'classifier__max_features': 0.5}. Best is trial 34 with value: 0.832.
# [16:24:17] INFO: Trial 46/50 - Accuracy: 0.8305 - Params: {'classifier__n_estimators': 322, 'classifier__learning_rate': 0.018563928219048356, 'classifier__max_depth': 3, 'classifier__min_samples_split': 4, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7844363768744325, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:24:17,761] Trial 45 finished with value: 0.8305 and parameters: {'classifier__n_estimators': 322, 'classifier__learning_rate': 0.018563928219048356, 'classifier__max_depth': 3, 'classifier__min_samples_split': 4, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7844363768744325, 'classifier__max_features': 0.5}. Best is trial 34 with value: 0.832.
# [16:24:25] INFO: Trial 47/50 - Accuracy: 0.8275 - Params: {'classifier__n_estimators': 316, 'classifier__learning_rate': 0.010845951411509104, 'classifier__max_depth': 5, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7771389788813218, 'classifier__max_features': None, 'classifier__random_state': 42}
# [I 2025-11-15 16:24:25,821] Trial 46 finished with value: 0.8275 and parameters: {'classifier__n_estimators': 316, 'classifier__learning_rate': 0.010845951411509104, 'classifier__max_depth': 5, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7771389788813218, 'classifier__max_features': None}. Best is trial 34 with value: 0.832.
# [16:24:28] INFO: Trial 48/50 - Accuracy: 0.8310 - Params: {'classifier__n_estimators': 324, 'classifier__learning_rate': 0.018854556247899557, 'classifier__max_depth': 3, 'classifier__min_samples_split': 4, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.745785842839834, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:24:28,621] Trial 47 finished with value: 0.831 and parameters: {'classifier__n_estimators': 324, 'classifier__learning_rate': 0.018854556247899557, 'classifier__max_depth': 3, 'classifier__min_samples_split': 4, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.745785842839834, 'classifier__max_features': 0.5}. Best is trial 34 with value: 0.832.
# [16:24:30] INFO: Trial 49/50 - Accuracy: 0.8305 - Params: {'classifier__n_estimators': 323, 'classifier__learning_rate': 0.02032211912534412, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 1, 'classifier__subsample': 0.7408353178667948, 'classifier__max_features': 'sqrt', 'classifier__random_state': 42}
# [I 2025-11-15 16:24:30,730] Trial 48 finished with value: 0.8305 and parameters: {'classifier__n_estimators': 323, 'classifier__learning_rate': 0.02032211912534412, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 1, 'classifier__subsample': 0.7408353178667948, 'classifier__max_features': 'sqrt'}. Best is trial 34 with value: 0.832.
# [16:24:33] INFO: Trial 50/50 - Accuracy: 0.8190 - Params: {'classifier__n_estimators': 308, 'classifier__learning_rate': 0.10951743789292782, 'classifier__max_depth': 4, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7120621046303011, 'classifier__max_features': 0.5, 'classifier__random_state': 42}
# [I 2025-11-15 16:24:33,949] Trial 49 finished with value: 0.819 and parameters: {'classifier__n_estimators': 308, 'classifier__learning_rate': 0.10951743789292782, 'classifier__max_depth': 4, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.7120621046303011, 'classifier__max_features': 0.5}. Best is trial 34 with value: 0.832.
# [16:24:33] INFO: Optimization finished. Best Accuracy: 0.8320
# [16:24:33] INFO: Best Parameters: {'classifier__n_estimators': 328, 'classifier__learning_rate': 0.023093275921250805, 'classifier__max_depth': 3, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.6681042240479405, 'classifier__max_features': 0.5}
# [16:24:33] INFO: Fitting the best pipeline on the provided training data...
# Best Gradient Boosting Accuracy: 0.832
# Best Gradient Boosting Params: {'classifier__n_estimators': 328, 'classifier__learning_rate': 0.023093275921250805, 'classifier__max_depth': 3, 'classifier__min_samples_split': 3, 'classifier__min_samples_leaf': 2, 'classifier__subsample': 0.6681042240479405, 'classifier__max_features': 0.5}
# '\n# --- CATBOOST ---\nbest_cat_model, best_params_cat, best_score_cat = optimize_optuna(\n    lambda: pipeline_catboost,\n    X_train_split,\n    y_train_split,\n    X_val_split,\n    y_val_split,\n    catboost_param_grid,\n    n_trials=1\n)\nprint("\nBest CatBoost Accuracy:", best_score_cat)\nprint("Best CatBoost Params:", best_params_cat)\n'

# %%
import optuna
from catboost import CatBoostClassifier, Pool
from sklearn.metrics import accuracy_score

# --- Clean data ---
X_train_cat = X_train_split[features].fillna(0).copy()
X_val_cat = X_val_split[features].fillna(0).copy()

# Ensure unique names
X_train_cat.columns = [
    f"{c}_{i}" if list(X_train_cat.columns).count(c) > 1 else c
    for i, c in enumerate(X_train_cat.columns)
]
X_val_cat.columns = X_train_cat.columns


# --- Optuna objective ---
def objective(trial):
    params = {
        'depth': trial.suggest_int('depth', 4, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'iterations': trial.suggest_int('iterations', 200, 1200),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 12),
        'random_seed': 42,
        'task_type': 'CPU',
        'verbose': 0,
    }

    train_pool = Pool(X_train_cat, y_train_split)
    val_pool = Pool(X_val_cat, y_val_split)

    model_cat = CatBoostClassifier(**params)
    model_cat.fit(
        train_pool,
        eval_set=val_pool,
        early_stopping_rounds=30
    )

    preds = model_cat.predict(X_val_cat)
    return accuracy_score(y_val_split, preds)


# --- Run search ---
study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=50)

print("Best Accuracy:", study.best_value)
print("Best Params:", study.best_params)


# --- Build final model using best params ---
cat_best = CatBoostClassifier(
    depth=study.best_params['depth'],
    learning_rate=study.best_params['learning_rate'],
    iterations=study.best_params['iterations'],
    l2_leaf_reg=study.best_params['l2_leaf_reg'],
    random_seed=42,
    task_type='CPU',
    verbose=0
)

train_pool = Pool(X_train_cat, y_train_split)
cat_best.fit(train_pool)
best_cat_model = cat_best
# Out:
# [I 2025-11-15 15:57:32,589] A new study created in memory with name: no-name-2c1a5aa2-d7f3-47b4-af59-ec624a804ea8
# [I 2025-11-15 15:57:33,525] Trial 0 finished with value: 0.8315 and parameters: {'depth': 6, 'learning_rate': 0.17254716573280354, 'iterations': 932, 'l2_leaf_reg': 7.585243326167403}. Best is trial 0 with value: 0.8315.
# [I 2025-11-15 15:57:35,061] Trial 1 finished with value: 0.827 and parameters: {'depth': 5, 'learning_rate': 0.015957084694148364, 'iterations': 258, 'l2_leaf_reg': 10.527937603524286}. Best is trial 0 with value: 0.8315.
# [I 2025-11-15 15:57:37,687] Trial 2 finished with value: 0.8375 and parameters: {'depth': 8, 'learning_rate': 0.08341106432362087, 'iterations': 220, 'l2_leaf_reg': 11.669008373781937}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:57:53,208] Trial 3 finished with value: 0.831 and parameters: {'depth': 9, 'learning_rate': 0.018891200276189388, 'iterations': 382, 'l2_leaf_reg': 3.017449608387772}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:57:56,343] Trial 4 finished with value: 0.8335 and parameters: {'depth': 6, 'learning_rate': 0.048164145309070844, 'iterations': 632, 'l2_leaf_reg': 4.203520542178461}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:58:09,685] Trial 5 finished with value: 0.832 and parameters: {'depth': 8, 'learning_rate': 0.01518747922672247, 'iterations': 492, 'l2_leaf_reg': 5.029980276230608}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:58:11,366] Trial 6 finished with value: 0.8355 and parameters: {'depth': 7, 'learning_rate': 0.10508421338691762, 'iterations': 399, 'l2_leaf_reg': 6.6565788225497275}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:58:29,209] Trial 7 finished with value: 0.832 and parameters: {'depth': 8, 'learning_rate': 0.011492999300221412, 'iterations': 808, 'l2_leaf_reg': 2.875765360560207}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:58:30,006] Trial 8 finished with value: 0.8345 and parameters: {'depth': 4, 'learning_rate': 0.17160445029754812, 'iterations': 1166, 'l2_leaf_reg': 9.892370829281072}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:58:42,913] Trial 9 finished with value: 0.836 and parameters: {'depth': 6, 'learning_rate': 0.013399060561509796, 'iterations': 884, 'l2_leaf_reg': 5.841677431135614}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:59:00,524] Trial 10 finished with value: 0.833 and parameters: {'depth': 10, 'learning_rate': 0.05334353369227191, 'iterations': 207, 'l2_leaf_reg': 11.50600774831963}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:59:05,703] Trial 11 finished with value: 0.8355 and parameters: {'depth': 7, 'learning_rate': 0.029257504643355754, 'iterations': 989, 'l2_leaf_reg': 8.580199427689973}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:59:13,260] Trial 12 finished with value: 0.8365 and parameters: {'depth': 8, 'learning_rate': 0.08554830985804554, 'iterations': 611, 'l2_leaf_reg': 5.479475769785468}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:59:17,205] Trial 13 finished with value: 0.832 and parameters: {'depth': 9, 'learning_rate': 0.08528776772069038, 'iterations': 673, 'l2_leaf_reg': 1.6733032771982086}. Best is trial 2 with value: 0.8375.
# [I 2025-11-15 15:59:19,499] Trial 14 finished with value: 0.838 and parameters: {'depth': 8, 'learning_rate': 0.084465150235137, 'iterations': 521, 'l2_leaf_reg': 8.61183201379625}. Best is trial 14 with value: 0.838.
# [I 2025-11-15 15:59:32,977] Trial 15 finished with value: 0.834 and parameters: {'depth': 10, 'learning_rate': 0.10852566368902125, 'iterations': 490, 'l2_leaf_reg': 8.732212804806332}. Best is trial 14 with value: 0.838.
# [I 2025-11-15 15:59:38,604] Trial 16 finished with value: 0.8325 and parameters: {'depth': 9, 'learning_rate': 0.06258991417271158, 'iterations': 323, 'l2_leaf_reg': 11.956181849221789}. Best is trial 14 with value: 0.838.
# [I 2025-11-15 15:59:51,456] Trial 17 finished with value: 0.84 and parameters: {'depth': 8, 'learning_rate': 0.03354527866527389, 'iterations': 511, 'l2_leaf_reg': 10.186780593162137}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:00:01,191] Trial 18 finished with value: 0.8345 and parameters: {'depth': 7, 'learning_rate': 0.0320465135385431, 'iterations': 521, 'l2_leaf_reg': 9.45307572026511}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:00:08,992] Trial 19 finished with value: 0.833 and parameters: {'depth': 9, 'learning_rate': 0.03346015126197764, 'iterations': 763, 'l2_leaf_reg': 7.115718872607186}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:00:18,329] Trial 20 finished with value: 0.8365 and parameters: {'depth': 5, 'learning_rate': 0.02379573165237773, 'iterations': 565, 'l2_leaf_reg': 7.936926220652932}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:00:21,683] Trial 21 finished with value: 0.8365 and parameters: {'depth': 8, 'learning_rate': 0.07201384222159787, 'iterations': 405, 'l2_leaf_reg': 10.964381275883504}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:00:23,219] Trial 22 finished with value: 0.833 and parameters: {'depth': 7, 'learning_rate': 0.12321920792394768, 'iterations': 318, 'l2_leaf_reg': 10.01066283167962}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:00:33,224] Trial 23 finished with value: 0.836 and parameters: {'depth': 8, 'learning_rate': 0.04105591952731792, 'iterations': 744, 'l2_leaf_reg': 9.04208097970616}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:00:39,584] Trial 24 finished with value: 0.8335 and parameters: {'depth': 9, 'learning_rate': 0.04231786283835091, 'iterations': 455, 'l2_leaf_reg': 10.861494847961398}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:00:41,470] Trial 25 finished with value: 0.8345 and parameters: {'depth': 8, 'learning_rate': 0.1375699596776107, 'iterations': 213, 'l2_leaf_reg': 10.163944232980315}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:00:50,186] Trial 26 finished with value: 0.8365 and parameters: {'depth': 7, 'learning_rate': 0.06439898880135952, 'iterations': 324, 'l2_leaf_reg': 11.599055985568755}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:06,292] Trial 27 finished with value: 0.836 and parameters: {'depth': 10, 'learning_rate': 0.08775613513687604, 'iterations': 562, 'l2_leaf_reg': 8.383606640856073}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:11,804] Trial 28 finished with value: 0.834 and parameters: {'depth': 8, 'learning_rate': 0.02352997917697856, 'iterations': 672, 'l2_leaf_reg': 9.289971994490344}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:12,486] Trial 29 finished with value: 0.836 and parameters: {'depth': 6, 'learning_rate': 0.1792164001339665, 'iterations': 1019, 'l2_leaf_reg': 7.360432773768076}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:21,022] Trial 30 finished with value: 0.835 and parameters: {'depth': 7, 'learning_rate': 0.05403215420680719, 'iterations': 427, 'l2_leaf_reg': 11.185947301836459}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:23,085] Trial 31 finished with value: 0.839 and parameters: {'depth': 8, 'learning_rate': 0.08127858777068601, 'iterations': 591, 'l2_leaf_reg': 5.684907687214547}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:27,698] Trial 32 finished with value: 0.8305 and parameters: {'depth': 9, 'learning_rate': 0.07326752239443525, 'iterations': 571, 'l2_leaf_reg': 6.095541151371211}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:29,979] Trial 33 finished with value: 0.8385 and parameters: {'depth': 8, 'learning_rate': 0.10350146250390607, 'iterations': 278, 'l2_leaf_reg': 4.506168555957724}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:38,092] Trial 34 finished with value: 0.833 and parameters: {'depth': 8, 'learning_rate': 0.13676799806194892, 'iterations': 286, 'l2_leaf_reg': 4.282181426314748}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:41,615] Trial 35 finished with value: 0.8305 and parameters: {'depth': 9, 'learning_rate': 0.10757466953008277, 'iterations': 627, 'l2_leaf_reg': 4.459010703467784}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:44,477] Trial 36 finished with value: 0.836 and parameters: {'depth': 7, 'learning_rate': 0.058084879823849564, 'iterations': 519, 'l2_leaf_reg': 3.6898595670012124}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:46,950] Trial 37 finished with value: 0.8335 and parameters: {'depth': 8, 'learning_rate': 0.15158397011263522, 'iterations': 362, 'l2_leaf_reg': 6.6601445242226465}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:01:59,594] Trial 38 finished with value: 0.831 and parameters: {'depth': 9, 'learning_rate': 0.03968886985668106, 'iterations': 737, 'l2_leaf_reg': 3.110929518179559}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:02:01,310] Trial 39 finished with value: 0.838 and parameters: {'depth': 7, 'learning_rate': 0.09608719822173237, 'iterations': 841, 'l2_leaf_reg': 5.167902967004474}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:02:05,037] Trial 40 finished with value: 0.833 and parameters: {'depth': 6, 'learning_rate': 0.07440990464717648, 'iterations': 451, 'l2_leaf_reg': 7.837046113763021}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:02:11,132] Trial 41 finished with value: 0.836 and parameters: {'depth': 8, 'learning_rate': 0.09488298606289487, 'iterations': 851, 'l2_leaf_reg': 5.035102949527115}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:02:12,674] Trial 42 finished with value: 0.8365 and parameters: {'depth': 7, 'learning_rate': 0.11483086267763738, 'iterations': 806, 'l2_leaf_reg': 5.2099224359914125}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:02:15,131] Trial 43 finished with value: 0.837 and parameters: {'depth': 8, 'learning_rate': 0.09715925451188613, 'iterations': 907, 'l2_leaf_reg': 6.399079514818898}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:02:17,596] Trial 44 finished with value: 0.834 and parameters: {'depth': 5, 'learning_rate': 0.04781863257719953, 'iterations': 995, 'l2_leaf_reg': 3.6695864375525944}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:02:22,858] Trial 45 finished with value: 0.8315 and parameters: {'depth': 7, 'learning_rate': 0.12854971186219974, 'iterations': 702, 'l2_leaf_reg': 4.5905793287017564}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:02:25,646] Trial 46 finished with value: 0.833 and parameters: {'depth': 6, 'learning_rate': 0.1515687793076619, 'iterations': 587, 'l2_leaf_reg': 5.6483796572509855}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:02:26,783] Trial 47 finished with value: 0.831 and parameters: {'depth': 8, 'learning_rate': 0.19466669948965798, 'iterations': 252, 'l2_leaf_reg': 2.104995538451334}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:02:28,976] Trial 48 finished with value: 0.8375 and parameters: {'depth': 7, 'learning_rate': 0.0694326894440998, 'iterations': 662, 'l2_leaf_reg': 3.9065941470085477}. Best is trial 17 with value: 0.84.
# [I 2025-11-15 16:02:31,745] Trial 49 finished with value: 0.8395 and parameters: {'depth': 8, 'learning_rate': 0.08159714325981898, 'iterations': 486, 'l2_leaf_reg': 6.262065962223292}. Best is trial 17 with value: 0.84.
# Best Accuracy: 0.84
# Best Params: {'depth': 8, 'learning_rate': 0.03354527866527389, 'iterations': 511, 'l2_leaf_reg': 10.186780593162137}

# %%
import optuna
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score

# --- 2. Scale numeric features ---
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_split[features])
X_val_scaled = scaler.transform(X_val_split[features])

# --- 3. Define Optuna objective for XGBoost ---
def xgb_objective(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 8),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
        'n_estimators': 300,
        'random_state': 42,
        'eval_metric': 'logloss',
        'use_label_encoder': False,
        'tree_method': 'hist',  # faster for tabular data
    }

    model = XGBClassifier(**params)

    # Early stopping
    model.fit(
        X_train_scaled, y_train_split,
        eval_set=[(X_val_scaled, y_val_split)],
        verbose=False
    )

    val_pred = model.predict(X_val_scaled)
    return accuracy_score(y_val_split, val_pred)

# --- 4. Run Optuna study ---
pruner = optuna.pruners.MedianPruner(n_warmup_steps=10)
sampler = optuna.samplers.TPESampler(seed=42)
study = optuna.create_study(direction='maximize', sampler=sampler, pruner=pruner)
study.optimize(xgb_objective, n_trials=80)

# --- 5. Best XGBoost model ---
best_xgb_params = study.best_params
best_xgb = XGBClassifier(
    **best_xgb_params,
    n_estimators=300,
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss',
    tree_method='hist'
)

best_xgb.fit(
    X_train_scaled, y_train_split,
    eval_set=[(X_val_scaled, y_val_split)],
    verbose=False
)

# --- 6. Evaluate ---
val_pred = best_xgb.predict(X_val_scaled)
val_acc = accuracy_score(y_val_split, val_pred)

print("\nBest XGBoost Accuracy:", round(val_acc, 4))
print("\nBest Parameters:")
for k, v in sorted(best_xgb_params.items()):
    print(f"  {k}: {v}")

# Optional: view trial history
#print(study.trials_dataframe(attrs=("number", "value", "params")))
# Out:
# [I 2025-11-15 16:08:41,038] A new study created in memory with name: no-name-35895c9b-736b-4803-90d0-d66b521d2e2f
# [I 2025-11-15 16:08:41,712] Trial 0 finished with value: 0.818 and parameters: {'max_depth': 5, 'learning_rate': 0.2536999076681772, 'subsample': 0.892797576724562, 'colsample_bytree': 0.8394633936788146, 'min_child_weight': 2, 'gamma': 0.7799726016810132, 'reg_lambda': 0.0017073967431528124, 'reg_alpha': 2.9154431891537547}. Best is trial 0 with value: 0.818.
# [I 2025-11-15 16:08:42,618] Trial 1 finished with value: 0.82 and parameters: {'max_depth': 6, 'learning_rate': 0.11114989443094977, 'subsample': 0.608233797718321, 'colsample_bytree': 0.9879639408647978, 'min_child_weight': 9, 'gamma': 1.0616955533913808, 'reg_lambda': 0.005337032762603957, 'reg_alpha': 0.00541524411940254}. Best is trial 1 with value: 0.82.
# [I 2025-11-15 16:08:43,344] Trial 2 finished with value: 0.8285 and parameters: {'max_depth': 4, 'learning_rate': 0.05958389350068958, 'subsample': 0.7727780074568463, 'colsample_bytree': 0.7164916560792167, 'min_child_weight': 7, 'gamma': 0.6974693032602092, 'reg_lambda': 0.01474275315991467, 'reg_alpha': 0.029204338471814112}. Best is trial 2 with value: 0.8285.
# [I 2025-11-15 16:08:44,047] Trial 3 finished with value: 0.8175 and parameters: {'max_depth': 5, 'learning_rate': 0.14447746112718687, 'subsample': 0.6798695128633439, 'colsample_bytree': 0.8056937753654446, 'min_child_weight': 6, 'gamma': 0.23225206359998862, 'reg_lambda': 0.26926469100861794, 'reg_alpha': 0.004809461967501573}. Best is trial 2 with value: 0.8285.
# [I 2025-11-15 16:08:44,659] Trial 4 finished with value: 0.825 and parameters: {'max_depth': 3, 'learning_rate': 0.2521267904777921, 'subsample': 0.9862528132298237, 'colsample_bytree': 0.9233589392465844, 'min_child_weight': 4, 'gamma': 0.48836057003191935, 'reg_lambda': 0.5456725485601477, 'reg_alpha': 0.057624872164786026}. Best is trial 2 with value: 0.8285.
# [I 2025-11-15 16:08:45,286] Trial 5 finished with value: 0.8335 and parameters: {'max_depth': 3, 'learning_rate': 0.05388108577817234, 'subsample': 0.6137554084460873, 'colsample_bytree': 0.9637281608315128, 'min_child_weight': 3, 'gamma': 3.31261142176991, 'reg_lambda': 0.017654048052495083, 'reg_alpha': 0.12030178871154672}. Best is trial 5 with value: 0.8335.
# [I 2025-11-15 16:08:46,030] Trial 6 finished with value: 0.833 and parameters: {'max_depth': 6, 'learning_rate': 0.01875220945578641, 'subsample': 0.9878338511058234, 'colsample_bytree': 0.9100531293444458, 'min_child_weight': 10, 'gamma': 4.474136752138244, 'reg_lambda': 0.24637685958997463, 'reg_alpha': 4.869640941520899}. Best is trial 5 with value: 0.8335.
# [I 2025-11-15 16:08:46,544] Trial 7 finished with value: 0.8285 and parameters: {'max_depth': 3, 'learning_rate': 0.01947558230629543, 'subsample': 0.6180909155642152, 'colsample_bytree': 0.7301321323053057, 'min_child_weight': 4, 'gamma': 1.3567451588694794, 'reg_lambda': 2.0651425578959257, 'reg_alpha': 0.026730883107816707}. Best is trial 5 with value: 0.8335.
# [I 2025-11-15 16:08:47,027] Trial 8 finished with value: 0.836 and parameters: {'max_depth': 4, 'learning_rate': 0.06333268775321843, 'subsample': 0.6563696899899051, 'colsample_bytree': 0.9208787923016158, 'min_child_weight': 1, 'gamma': 4.9344346830025865, 'reg_lambda': 1.2273800987852967, 'reg_alpha': 0.0062353771356731605}. Best is trial 8 with value: 0.836.
# [I 2025-11-15 16:08:47,627] Trial 9 finished with value: 0.8235 and parameters: {'max_depth': 3, 'learning_rate': 0.1601531217136121, 'subsample': 0.8827429375390468, 'colsample_bytree': 0.8916028672163949, 'min_child_weight': 8, 'gamma': 0.3702232586704518, 'reg_lambda': 0.02715581955282941, 'reg_alpha': 0.0029072088906598446}. Best is trial 8 with value: 0.836.
# [I 2025-11-15 16:08:48,640] Trial 10 finished with value: 0.8335 and parameters: {'max_depth': 8, 'learning_rate': 0.010206070557577008, 'subsample': 0.7230776845801049, 'colsample_bytree': 0.6071847502459279, 'min_child_weight': 1, 'gamma': 4.538323976412588, 'reg_lambda': 7.297929454294199, 'reg_alpha': 0.5077750882056776}. Best is trial 8 with value: 0.836.
# [I 2025-11-15 16:08:49,291] Trial 11 finished with value: 0.835 and parameters: {'max_depth': 4, 'learning_rate': 0.05066279925177419, 'subsample': 0.6681139558702258, 'colsample_bytree': 0.9783238879894852, 'min_child_weight': 3, 'gamma': 3.344528550358621, 'reg_lambda': 0.039523569540817725, 'reg_alpha': 0.3007016232607128}. Best is trial 8 with value: 0.836.
# [I 2025-11-15 16:08:49,907] Trial 12 finished with value: 0.836 and parameters: {'max_depth': 4, 'learning_rate': 0.05212573085285519, 'subsample': 0.7067964291781478, 'colsample_bytree': 0.9872607155373294, 'min_child_weight': 1, 'gamma': 3.44768300560321, 'reg_lambda': 0.07495849797769727, 'reg_alpha': 0.41873572081560717}. Best is trial 8 with value: 0.836.
# [I 2025-11-15 16:08:50,487] Trial 13 finished with value: 0.8345 and parameters: {'max_depth': 4, 'learning_rate': 0.032629220484119155, 'subsample': 0.7722947680183979, 'colsample_bytree': 0.8645697008002724, 'min_child_weight': 1, 'gamma': 4.97421671024512, 'reg_lambda': 1.5837630309310902, 'reg_alpha': 1.0633794548169282}. Best is trial 8 with value: 0.836.
# [I 2025-11-15 16:08:51,107] Trial 14 finished with value: 0.8325 and parameters: {'max_depth': 7, 'learning_rate': 0.08626365289537273, 'subsample': 0.7036719540871451, 'colsample_bytree': 0.9995405088021476, 'min_child_weight': 1, 'gamma': 3.580839787370531, 'reg_lambda': 0.11475459811783101, 'reg_alpha': 0.011503239100948241}. Best is trial 8 with value: 0.836.
# [I 2025-11-15 16:08:51,857] Trial 15 finished with value: 0.835 and parameters: {'max_depth': 5, 'learning_rate': 0.030300384613298953, 'subsample': 0.8235194332173258, 'colsample_bytree': 0.9329582117099475, 'min_child_weight': 5, 'gamma': 2.127947321819143, 'reg_lambda': 9.682841209700303, 'reg_alpha': 0.0010357669780885917}. Best is trial 8 with value: 0.836.
# [I 2025-11-15 16:08:52,423] Trial 16 finished with value: 0.834 and parameters: {'max_depth': 4, 'learning_rate': 0.08127679633454948, 'subsample': 0.736425258169701, 'colsample_bytree': 0.7856665984179805, 'min_child_weight': 2, 'gamma': 2.5845143083780195, 'reg_lambda': 1.1239701171956262, 'reg_alpha': 0.1616010999420248}. Best is trial 8 with value: 0.836.
# [I 2025-11-15 16:08:58,424] Trial 17 finished with value: 0.835 and parameters: {'max_depth': 4, 'learning_rate': 0.035222854859289485, 'subsample': 0.6651164041768274, 'colsample_bytree': 0.9438599500782205, 'min_child_weight': 3, 'gamma': 3.964539468260549, 'reg_lambda': 0.11597828588631855, 'reg_alpha': 1.00736627845721}. Best is trial 8 with value: 0.836.
# [I 2025-11-15 16:08:58,981] Trial 18 finished with value: 0.835 and parameters: {'max_depth': 5, 'learning_rate': 0.07436392998702257, 'subsample': 0.8288417040245744, 'colsample_bytree': 0.8758697700847069, 'min_child_weight': 5, 'gamma': 2.533881284358335, 'reg_lambda': 3.4422830104069533, 'reg_alpha': 8.284467091705128}. Best is trial 8 with value: 0.836.
# [I 2025-11-15 16:08:59,708] Trial 19 finished with value: 0.837 and parameters: {'max_depth': 6, 'learning_rate': 0.04081464553734502, 'subsample': 0.6571384273711746, 'colsample_bytree': 0.6047124226843672, 'min_child_weight': 2, 'gamma': 4.009803002436079, 'reg_lambda': 0.5403133461522815, 'reg_alpha': 0.025627310128633642}. Best is trial 19 with value: 0.837.
# [I 2025-11-15 16:09:00,628] Trial 20 finished with value: 0.835 and parameters: {'max_depth': 7, 'learning_rate': 0.01766854861004816, 'subsample': 0.6432286784493509, 'colsample_bytree': 0.6243018652148721, 'min_child_weight': 2, 'gamma': 4.9117147831289145, 'reg_lambda': 0.5219899487237296, 'reg_alpha': 0.014133942032757868}. Best is trial 19 with value: 0.837.
# [I 2025-11-15 16:09:01,351] Trial 21 finished with value: 0.8375 and parameters: {'max_depth': 6, 'learning_rate': 0.044487102375380824, 'subsample': 0.7024809980331705, 'colsample_bytree': 0.6880406149708346, 'min_child_weight': 1, 'gamma': 3.9414688372360764, 'reg_lambda': 0.06284376523824818, 'reg_alpha': 0.054433738059108214}. Best is trial 21 with value: 0.8375.
# [I 2025-11-15 16:09:02,163] Trial 22 finished with value: 0.84 and parameters: {'max_depth': 6, 'learning_rate': 0.04000192789455315, 'subsample': 0.6468329412700768, 'colsample_bytree': 0.6656640225399384, 'min_child_weight': 2, 'gamma': 4.108450445486941, 'reg_lambda': 0.7260042638664883, 'reg_alpha': 0.05246845012264984}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:02,850] Trial 23 finished with value: 0.8355 and parameters: {'max_depth': 7, 'learning_rate': 0.03972460239812125, 'subsample': 0.7526597646391255, 'colsample_bytree': 0.6549612269166183, 'min_child_weight': 4, 'gamma': 3.9292344701696886, 'reg_lambda': 0.38566254985232007, 'reg_alpha': 0.05039214346313542}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:03,750] Trial 24 finished with value: 0.834 and parameters: {'max_depth': 6, 'learning_rate': 0.02481406809800782, 'subsample': 0.6926870687337884, 'colsample_bytree': 0.6752623885974618, 'min_child_weight': 2, 'gamma': 2.887957332693476, 'reg_lambda': 0.16968745268494398, 'reg_alpha': 0.07698678459644591}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:04,420] Trial 25 finished with value: 0.8355 and parameters: {'max_depth': 6, 'learning_rate': 0.040383700461943804, 'subsample': 0.6388121932528018, 'colsample_bytree': 0.6936947222336914, 'min_child_weight': 3, 'gamma': 4.126108186207141, 'reg_lambda': 0.05297995663949812, 'reg_alpha': 0.029329871716798028}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:05,768] Trial 26 finished with value: 0.8335 and parameters: {'max_depth': 8, 'learning_rate': 0.023343435937010548, 'subsample': 0.6359912772439344, 'colsample_bytree': 0.6347264216551218, 'min_child_weight': 2, 'gamma': 1.9496281916023785, 'reg_lambda': 0.7148028895872912, 'reg_alpha': 0.18701061533120145}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:06,662] Trial 27 finished with value: 0.8345 and parameters: {'max_depth': 7, 'learning_rate': 0.011424314129558686, 'subsample': 0.6851789294586402, 'colsample_bytree': 0.7358104190683467, 'min_child_weight': 4, 'gamma': 4.3662080017133444, 'reg_lambda': 4.0537149116778215, 'reg_alpha': 0.014994162419656025}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:10,468] Trial 28 finished with value: 0.835 and parameters: {'max_depth': 6, 'learning_rate': 0.013788964662433716, 'subsample': 0.7351580032710945, 'colsample_bytree': 0.6020232179616668, 'min_child_weight': 6, 'gamma': 2.964873390993781, 'reg_lambda': 0.0034552753483826533, 'reg_alpha': 0.05348900329427431}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:13,393] Trial 29 finished with value: 0.837 and parameters: {'max_depth': 5, 'learning_rate': 0.043715521457166145, 'subsample': 0.7846780493863432, 'colsample_bytree': 0.7670071824132911, 'min_child_weight': 2, 'gamma': 3.807274367631189, 'reg_lambda': 0.1586180481285433, 'reg_alpha': 0.002061242209089413}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:14,286] Trial 30 finished with value: 0.834 and parameters: {'max_depth': 7, 'learning_rate': 0.027226348998098764, 'subsample': 0.8848925052669799, 'colsample_bytree': 0.657047737987441, 'min_child_weight': 1, 'gamma': 2.995197872145816, 'reg_lambda': 0.0014824522730226873, 'reg_alpha': 0.10321441718082211}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:14,903] Trial 31 finished with value: 0.83 and parameters: {'max_depth': 5, 'learning_rate': 0.04303061432598103, 'subsample': 0.801245966321592, 'colsample_bytree': 0.76147804607218, 'min_child_weight': 2, 'gamma': 3.763163883321167, 'reg_lambda': 0.21836025524718128, 'reg_alpha': 0.0027221746453454}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:15,601] Trial 32 finished with value: 0.832 and parameters: {'max_depth': 6, 'learning_rate': 0.043467169758665054, 'subsample': 0.9359353824726453, 'colsample_bytree': 0.7017717940933965, 'min_child_weight': 3, 'gamma': 4.243315395379464, 'reg_lambda': 0.09088071410095896, 'reg_alpha': 0.009122293496201686}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:16,466] Trial 33 finished with value: 0.8385 and parameters: {'max_depth': 6, 'learning_rate': 0.0674288260182983, 'subsample': 0.6010264319394327, 'colsample_bytree': 0.815040501237642, 'min_child_weight': 2, 'gamma': 3.7185987909170035, 'reg_lambda': 0.8050011789113894, 'reg_alpha': 0.001263067015211865}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:17,204] Trial 34 finished with value: 0.832 and parameters: {'max_depth': 6, 'learning_rate': 0.11214503717809357, 'subsample': 0.6066243808538055, 'colsample_bytree': 0.823008048869822, 'min_child_weight': 2, 'gamma': 4.609430062246614, 'reg_lambda': 0.8570185238783694, 'reg_alpha': 0.02831149748567621}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:17,977] Trial 35 finished with value: 0.8335 and parameters: {'max_depth': 6, 'learning_rate': 0.11175677930442286, 'subsample': 0.6033219627762438, 'colsample_bytree': 0.6430441778895508, 'min_child_weight': 3, 'gamma': 3.6960481526575597, 'reg_lambda': 0.008403543391391995, 'reg_alpha': 0.0015501803456672446}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:18,614] Trial 36 finished with value: 0.839 and parameters: {'max_depth': 7, 'learning_rate': 0.06691856979570655, 'subsample': 0.6311631983195253, 'colsample_bytree': 0.6768856196246542, 'min_child_weight': 7, 'gamma': 4.175839860049385, 'reg_lambda': 2.7721786052878237, 'reg_alpha': 0.004695888420771239}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:19,487] Trial 37 finished with value: 0.83 and parameters: {'max_depth': 7, 'learning_rate': 0.06642728715036895, 'subsample': 0.6278512724336994, 'colsample_bytree': 0.8338424382692133, 'min_child_weight': 7, 'gamma': 3.172573142671827, 'reg_lambda': 2.5113414377847025, 'reg_alpha': 0.004470821563221997}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:20,853] Trial 38 finished with value: 0.8315 and parameters: {'max_depth': 8, 'learning_rate': 0.08895602695080435, 'subsample': 0.6742304970957645, 'colsample_bytree': 0.67952340098862, 'min_child_weight': 7, 'gamma': 0.01333980638640675, 'reg_lambda': 4.699637793053235, 'reg_alpha': 0.0010683550614914855}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:21,460] Trial 39 finished with value: 0.828 and parameters: {'max_depth': 7, 'learning_rate': 0.16076173265737595, 'subsample': 0.623656182660727, 'colsample_bytree': 0.725524568926866, 'min_child_weight': 8, 'gamma': 4.6857417241776105, 'reg_lambda': 0.3468559493468788, 'reg_alpha': 0.004023958473315505}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:22,279] Trial 40 finished with value: 0.8345 and parameters: {'max_depth': 6, 'learning_rate': 0.05664708196986178, 'subsample': 0.6507385537384884, 'colsample_bytree': 0.7519849993125655, 'min_child_weight': 9, 'gamma': 4.25547033397276, 'reg_lambda': 0.019185672859568882, 'reg_alpha': 0.008633116454283848}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:27,962] Trial 41 finished with value: 0.8335 and parameters: {'max_depth': 6, 'learning_rate': 0.06977956008665741, 'subsample': 0.6598983859586687, 'colsample_bytree': 0.6680662692219345, 'min_child_weight': 8, 'gamma': 4.058417025590006, 'reg_lambda': 2.0224521065464516, 'reg_alpha': 0.02041192211429611}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:29,216] Trial 42 finished with value: 0.833 and parameters: {'max_depth': 6, 'learning_rate': 0.05278403763495975, 'subsample': 0.6163145867861733, 'colsample_bytree': 0.701505870776739, 'min_child_weight': 6, 'gamma': 3.5769816190723622, 'reg_lambda': 0.635881922960879, 'reg_alpha': 0.04396645363987645}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:29,803] Trial 43 finished with value: 0.832 and parameters: {'max_depth': 5, 'learning_rate': 0.09516619530432752, 'subsample': 0.6009101314088954, 'colsample_bytree': 0.6344581158931835, 'min_child_weight': 1, 'gamma': 4.391906679668482, 'reg_lambda': 0.42745893696803583, 'reg_alpha': 0.006907421137705188}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:30,595] Trial 44 finished with value: 0.8375 and parameters: {'max_depth': 7, 'learning_rate': 0.03723477940730782, 'subsample': 0.7114858263882782, 'colsample_bytree': 0.8022823878114349, 'min_child_weight': 5, 'gamma': 3.2023080477634593, 'reg_lambda': 1.131249497873519, 'reg_alpha': 0.019091698853906165}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:31,474] Trial 45 finished with value: 0.837 and parameters: {'max_depth': 8, 'learning_rate': 0.03514589916657441, 'subsample': 0.7087963735486438, 'colsample_bytree': 0.8146089428782108, 'min_child_weight': 5, 'gamma': 3.298556650768087, 'reg_lambda': 0.9851866421336211, 'reg_alpha': 0.0032542292408834087}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:32,207] Trial 46 finished with value: 0.834 and parameters: {'max_depth': 7, 'learning_rate': 0.060748682188789524, 'subsample': 0.6902480045232434, 'colsample_bytree': 0.7903378466832955, 'min_child_weight': 10, 'gamma': 2.801431889960021, 'reg_lambda': 1.6228700064770807, 'reg_alpha': 0.00175378162190371}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:32,791] Trial 47 finished with value: 0.8235 and parameters: {'max_depth': 7, 'learning_rate': 0.13270073638832944, 'subsample': 0.7189970656634828, 'colsample_bytree': 0.8558843453660596, 'min_child_weight': 7, 'gamma': 3.1521519553453556, 'reg_lambda': 2.7168892470445813, 'reg_alpha': 0.005726677348738498}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:34,052] Trial 48 finished with value: 0.837 and parameters: {'max_depth': 8, 'learning_rate': 0.028041051706484254, 'subsample': 0.7465923851414529, 'colsample_bytree': 0.8012999685899299, 'min_child_weight': 4, 'gamma': 2.094304184867286, 'reg_lambda': 0.2534159293979032, 'reg_alpha': 0.07827498430422884}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:34,763] Trial 49 finished with value: 0.8375 and parameters: {'max_depth': 7, 'learning_rate': 0.04780561172610599, 'subsample': 0.6291105444931978, 'colsample_bytree': 0.7420064565761836, 'min_child_weight': 8, 'gamma': 3.465852658484341, 'reg_lambda': 5.747298431623342, 'reg_alpha': 0.0384413526816153}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:35,215] Trial 50 finished with value: 0.8235 and parameters: {'max_depth': 5, 'learning_rate': 0.2877083404622371, 'subsample': 0.6752169336793423, 'colsample_bytree': 0.7734438848659223, 'min_child_weight': 6, 'gamma': 4.684740102449495, 'reg_lambda': 1.1126029097740782, 'reg_alpha': 0.1534270222597222}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:35,943] Trial 51 finished with value: 0.835 and parameters: {'max_depth': 7, 'learning_rate': 0.048197902388578524, 'subsample': 0.6309528566417593, 'colsample_bytree': 0.7427654098307187, 'min_child_weight': 9, 'gamma': 3.5149810835165294, 'reg_lambda': 6.323510084404794, 'reg_alpha': 0.03837777122279647}. Best is trial 22 with value: 0.84.
# [I 2025-11-15 16:09:36,771] Trial 52 finished with value: 0.842 and parameters: {'max_depth': 7, 'learning_rate': 0.03449309051213638, 'subsample': 0.6427843406338178, 'colsample_bytree': 0.7113594634696728, 'min_child_weight': 9, 'gamma': 3.685451015111078, 'reg_lambda': 5.698950693580417, 'reg_alpha': 0.01716572534089344}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:09:37,538] Trial 53 finished with value: 0.8375 and parameters: {'max_depth': 7, 'learning_rate': 0.035139625261619366, 'subsample': 0.6496372576384613, 'colsample_bytree': 0.7192488602575414, 'min_child_weight': 10, 'gamma': 3.8419910403324438, 'reg_lambda': 3.372125276079032, 'reg_alpha': 0.019463209367019178}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:09:38,113] Trial 54 finished with value: 0.8375 and parameters: {'max_depth': 6, 'learning_rate': 0.058124259924123345, 'subsample': 0.6980582260596884, 'colsample_bytree': 0.6881352492206545, 'min_child_weight': 9, 'gamma': 4.1715515756925035, 'reg_lambda': 8.829427942925346, 'reg_alpha': 0.014768252515855174}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:09:41,347] Trial 55 finished with value: 0.8385 and parameters: {'max_depth': 8, 'learning_rate': 0.022291921107301577, 'subsample': 0.6706488592840277, 'colsample_bytree': 0.6599610581412844, 'min_child_weight': 5, 'gamma': 3.662486075072675, 'reg_lambda': 1.548851236154949, 'reg_alpha': 0.010648281854877532}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:09:46,524] Trial 56 finished with value: 0.8395 and parameters: {'max_depth': 8, 'learning_rate': 0.020732756943746506, 'subsample': 0.6695505554466193, 'colsample_bytree': 0.6634431233978535, 'min_child_weight': 1, 'gamma': 1.5667897262334565, 'reg_lambda': 1.7369619676141133, 'reg_alpha': 0.009932837023618638}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:09:47,658] Trial 57 finished with value: 0.836 and parameters: {'max_depth': 8, 'learning_rate': 0.017291330064294626, 'subsample': 0.6160722991022786, 'colsample_bytree': 0.6184264274185685, 'min_child_weight': 7, 'gamma': 1.0074322451385638, 'reg_lambda': 1.573693059130669, 'reg_alpha': 0.008271172422131422}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:09:48,833] Trial 58 finished with value: 0.836 and parameters: {'max_depth': 8, 'learning_rate': 0.022092455450636938, 'subsample': 0.6671454374720207, 'colsample_bytree': 0.6598989215876201, 'min_child_weight': 9, 'gamma': 1.3643695614877978, 'reg_lambda': 2.030433418842827, 'reg_alpha': 0.010954649941752815}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:09:50,364] Trial 59 finished with value: 0.835 and parameters: {'max_depth': 8, 'learning_rate': 0.02043646523147794, 'subsample': 0.8588982860225294, 'colsample_bytree': 0.7066862581574966, 'min_child_weight': 3, 'gamma': 1.2632323236552452, 'reg_lambda': 3.0761569600016188, 'reg_alpha': 0.005220526388616682}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:09:51,637] Trial 60 finished with value: 0.834 and parameters: {'max_depth': 8, 'learning_rate': 0.0314526446124725, 'subsample': 0.641594104704219, 'colsample_bytree': 0.6458879599460726, 'min_child_weight': 1, 'gamma': 1.912398918995764, 'reg_lambda': 4.94865981968242, 'reg_alpha': 0.0022521036548512263}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:09:53,319] Trial 61 finished with value: 0.8365 and parameters: {'max_depth': 8, 'learning_rate': 0.015389637526178487, 'subsample': 0.6805752034916578, 'colsample_bytree': 0.6815230841744341, 'min_child_weight': 1, 'gamma': 1.7239591511542303, 'reg_lambda': 0.04366693094010968, 'reg_alpha': 0.011414206154230838}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:09:54,242] Trial 62 finished with value: 0.8365 and parameters: {'max_depth': 6, 'learning_rate': 0.026782340906327858, 'subsample': 0.6571561396202241, 'colsample_bytree': 0.6671600004970487, 'min_child_weight': 1, 'gamma': 3.7147412488189264, 'reg_lambda': 1.5816771360242978, 'reg_alpha': 0.08100094438679713}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:09:56,440] Trial 63 finished with value: 0.8355 and parameters: {'max_depth': 8, 'learning_rate': 0.07966492364353651, 'subsample': 0.6433955475583503, 'colsample_bytree': 0.7082728462211945, 'min_child_weight': 2, 'gamma': 4.033347505784912, 'reg_lambda': 0.06632281386207754, 'reg_alpha': 0.001461539063486239}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:02,500] Trial 64 finished with value: 0.836 and parameters: {'max_depth': 7, 'learning_rate': 0.029516007448619354, 'subsample': 0.616058883100732, 'colsample_bytree': 0.6904315581728909, 'min_child_weight': 1, 'gamma': 2.409502086598294, 'reg_lambda': 0.026861946935998252, 'reg_alpha': 0.003376374793701949}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:03,657] Trial 65 finished with value: 0.8335 and parameters: {'max_depth': 6, 'learning_rate': 0.025110419917554486, 'subsample': 0.6684238418097451, 'colsample_bytree': 0.6247319806564154, 'min_child_weight': 4, 'gamma': 0.7544754882632122, 'reg_lambda': 4.028716686184756, 'reg_alpha': 0.006279160049874421}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:05,206] Trial 66 finished with value: 0.836 and parameters: {'max_depth': 8, 'learning_rate': 0.014492995705577405, 'subsample': 0.6839033218500494, 'colsample_bytree': 0.6466663256009183, 'min_child_weight': 2, 'gamma': 3.6406373230941838, 'reg_lambda': 7.794438514537031, 'reg_alpha': 0.06608134710064265}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:06,460] Trial 67 finished with value: 0.838 and parameters: {'max_depth': 7, 'learning_rate': 0.020864590214318805, 'subsample': 0.7278795267552057, 'colsample_bytree': 0.670061395858949, 'min_child_weight': 3, 'gamma': 4.425338437953052, 'reg_lambda': 0.8248666695980189, 'reg_alpha': 0.21672303692671088}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:07,938] Trial 68 finished with value: 0.84 and parameters: {'max_depth': 7, 'learning_rate': 0.019868474017141605, 'subsample': 0.7660424046306339, 'colsample_bytree': 0.6741711274059375, 'min_child_weight': 3, 'gamma': 4.816420353609357, 'reg_lambda': 0.8131919785596965, 'reg_alpha': 0.4086405432430914}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:09,925] Trial 69 finished with value: 0.8365 and parameters: {'max_depth': 7, 'learning_rate': 0.01259427290426625, 'subsample': 0.9225695727970166, 'colsample_bytree': 0.6205950070139359, 'min_child_weight': 4, 'gamma': 4.7842927295357525, 'reg_lambda': 1.3777146501583741, 'reg_alpha': 0.9451174188687611}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:18,239] Trial 70 finished with value: 0.8375 and parameters: {'max_depth': 8, 'learning_rate': 0.018411137756543426, 'subsample': 0.7616511229128933, 'colsample_bytree': 0.6512841262037925, 'min_child_weight': 2, 'gamma': 0.5298471810181318, 'reg_lambda': 2.4358922175538087, 'reg_alpha': 0.5213273739027011}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:19,487] Trial 71 finished with value: 0.8395 and parameters: {'max_depth': 7, 'learning_rate': 0.02098191186309764, 'subsample': 0.7332888429862654, 'colsample_bytree': 0.6760925166284684, 'min_child_weight': 3, 'gamma': 4.561705547574027, 'reg_lambda': 0.826511539470939, 'reg_alpha': 0.23401528362722632}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:20,521] Trial 72 finished with value: 0.8335 and parameters: {'max_depth': 7, 'learning_rate': 0.023353475104117293, 'subsample': 0.7960484952488727, 'colsample_bytree': 0.6351467698266353, 'min_child_weight': 3, 'gamma': 4.982381110293696, 'reg_lambda': 0.5775049506742636, 'reg_alpha': 0.3870144102766194}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:21,859] Trial 73 finished with value: 0.838 and parameters: {'max_depth': 7, 'learning_rate': 0.0158392210147435, 'subsample': 0.7675015165376486, 'colsample_bytree': 0.6630862011985459, 'min_child_weight': 3, 'gamma': 4.550321896465409, 'reg_lambda': 0.8003160156131712, 'reg_alpha': 0.6632815654301607}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:22,970] Trial 74 finished with value: 0.836 and parameters: {'max_depth': 7, 'learning_rate': 0.017278217422975143, 'subsample': 0.7437655342164835, 'colsample_bytree': 0.7150935449575693, 'min_child_weight': 6, 'gamma': 4.767992121948526, 'reg_lambda': 0.47461113868559485, 'reg_alpha': 0.3088892864231635}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:24,134] Trial 75 finished with value: 0.8365 and parameters: {'max_depth': 8, 'learning_rate': 0.02159718099325278, 'subsample': 0.8092160166290262, 'colsample_bytree': 0.6729542762354802, 'min_child_weight': 2, 'gamma': 4.307337203157293, 'reg_lambda': 0.332372404939711, 'reg_alpha': 1.6975159998809841}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:27,978] Trial 76 finished with value: 0.8305 and parameters: {'max_depth': 7, 'learning_rate': 0.010122009964156829, 'subsample': 0.6380770620346218, 'colsample_bytree': 0.6964695680080205, 'min_child_weight': 3, 'gamma': 4.489161076443681, 'reg_lambda': 1.9884015363788277, 'reg_alpha': 0.13389568283547243}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:31,791] Trial 77 finished with value: 0.837 and parameters: {'max_depth': 6, 'learning_rate': 0.03170290271073949, 'subsample': 0.6000502771456364, 'colsample_bytree': 0.68008793446717, 'min_child_weight': 4, 'gamma': 4.830427406589663, 'reg_lambda': 0.6795055865021948, 'reg_alpha': 0.27012006448100745}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:32,707] Trial 78 finished with value: 0.8365 and parameters: {'max_depth': 7, 'learning_rate': 0.019189272708774643, 'subsample': 0.784026926638423, 'colsample_bytree': 0.637930845413343, 'min_child_weight': 5, 'gamma': 3.890540177529698, 'reg_lambda': 0.9617850654767204, 'reg_alpha': 0.022693710425346493}. Best is trial 52 with value: 0.842.
# [I 2025-11-15 16:10:33,639] Trial 79 finished with value: 0.837 and parameters: {'max_depth': 8, 'learning_rate': 0.024765723708418952, 'subsample': 0.6508800745643378, 'colsample_bytree': 0.6557264190930796, 'min_child_weight': 2, 'gamma': 4.2417925075100555, 'reg_lambda': 0.17612825689375247, 'reg_alpha': 0.01613611221643957}. Best is trial 52 with value: 0.842.
# Best XGBoost Accuracy: 0.842
#
# Best Parameters:
#   colsample_bytree: 0.7113594634696728
#   gamma: 3.685451015111078
#   learning_rate: 0.03449309051213638
#   max_depth: 7
#   min_child_weight: 9
#   reg_alpha: 0.01716572534089344
#   reg_lambda: 5.698950693580417
#   subsample: 0.6427843406338178

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# --- Base models (already fitted) ---
#xgb_clf = best_model.named_steps["classifier"]
lgbm_clf = best_lgbm_model.named_steps["classifier"]
#gb_clf = best_gb_model.named_steps["classifier"]
#cat_clf = best_cat_model.named_steps["classifier"]


# --- Final estimator with scaling to help convergence ---
final_estimator = make_pipeline(
    StandardScaler(),
    LogisticRegression(max_iter=5000, solver="saga", random_state=42)
)

# --- Stacking classifier ---
stacking_model = StackingClassifier(
    estimators=[
        ("xgb", best_xgb),
        #("lgbm", lgbm_clf),
        #("gb", gb_clf),
        ("cat", best_cat_model)
    ],
    final_estimator=final_estimator,
    passthrough=False,  # only use base model predictions, easier to converge
    n_jobs=-1,
    cv=2  # cross-validated predictions for the final estimator
)

# --- Fit stacking model with preprocessed features ---
X_train_preprocessed = best_model.named_steps["preprocessor"].transform(X_train_split)
X_val_preprocessed = best_model.named_steps["preprocessor"].transform(X_val_split)

stacking_model.fit(X_train_preprocessed, y_train_split)

# --- Predict and evaluate ---
stack_preds = stacking_model.predict(X_val_preprocessed)
from sklearn.metrics import accuracy_score
stack_acc = accuracy_score(y_val_split, stack_preds)
print(f"Stacking Ensemble Validation Accuracy: {stack_acc:.4f}")
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] lambda_l1 is set=10.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=10.0
# [LightGBM] [Warning] lambda_l2 is set=5.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.0
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# Stacking Ensemble Validation Accuracy: 0.8385

# %%
final_model = stacking_model

from Submission.submit import save_submission
import pandas as pd

X_test_for_submission = X_test_features[features] 

# Agora o 'final_model' receberá as 58 features que ele espera.
save_submission(X_test_for_submission, final_model, name = 'olya_model')
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] lambda_l1 is set=10.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=10.0
# [LightGBM] [Warning] lambda_l2 is set=5.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.0
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [INFO] Submission created: submissions\olya_model.csv
# 'submissions\\olya_model.csv'
